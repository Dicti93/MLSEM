# %% [markdown]
# ## Setup and Configuration for Data Analysis
#
# ### Libraries and Packages
# - **Pandas**: For data manipulation and analysis.
# - **Matplotlib** and **Seaborn**: For data visualization.
# - **Glob** and **OS**: For file operations across operating systems.
# - **re**: For regular expression operations.
# - **NumPy**: For numerical operations on arrays.
# - **scikit-learn**: Specifically, `GroupShuffleSplit` for generating training/testing sets.
# - **shutil** and **cv2**: For operations related to file management and image processing.
# - **Pathlib**: For easy manipulation of file paths.
#
# ### Configuration
# - **Pandas Display Options**: Configured to ensure that the display of dataframes in this notebook is not truncated, facilitating the exploration of datasets with many rows or columns.

# %%
# Packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os
import re
import numpy as np
from sklearn.model_selection import GroupShuffleSplit
from shutil import copyfile
import cv2
from pathlib import Path
from shutil import rmtree
import importlib

import sys
import os


# Set display options
pd.set_option('display.max_columns', None) 
pd.set_option('display.max_rows', None)

# %%
# Construct the absolute path to the 'lib' directory based on your current working directory
current_dir = os.getcwd()  # Get the current working directory
lib_path = os.path.abspath(os.path.join(current_dir, 'lib'))  # Go up one level and then access the 'lib' directory

# Add the 'lib' directory to sys.path if it's not already there
if lib_path not in sys.path:
    sys.path.append(lib_path)

import prep_images as pi

import importlib
import prep_images
importlib.reload(prep_images)


print(dir(prep_images))  # Check again
# Out:
# ['Path', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '__warningregistry__', 'check_for_overlap', 'convert_column_to_string', 'crop_and_resize_image', 'cv2', 'extract_image_labels', 'extract_patient_codes', 'find_image_border', 'glob', 'missing_counts', 'np', 'os', 'pd', 'preprocess_us_number', 'process_images_and_create_csv', 'process_images_in_directory', 're', 'rename_files_in_directory', 'rmtree', 'test_split', 'write_records_to_csv']

# %%
# Relative path to the CSV file
relative_path = '../2. Data and Description/data.csv'

# Read the CSV file
df = pd.read_csv(relative_path, delimiter=";")

# %% [markdown]
# ## Configuration of Constants and Directory Setup
#
# This section defines essential constants and directory paths used throughout the notebook for managing and processing ultrasound images:
#
# - **Directories**: Sets up paths for raw and processed images, categorized into training, test, and other specific uses.
# - **Image Processing Parameters**: Configures the type of padding for images and identifies the target variable for prediction tasks.
# - **Features**: Lists specific tabular features and categorizes them into continuously valued and binary valued for structured processing.
# - **Directory Initialization**: Ensures all specified directories exist, creating them if necessary to prevent runtime errors when saving files.

# %%
# Important constants

# Directories
# Directory with the original, unprocessed ultrasound images
IMAGE_DIR = 'USPictures'
# Directory for saving unprocessed ultrasound images from the training set
TRAIN_IMAGE_DIR = 'USPictures/Train'
# Directory for saving unprocessed ultrasound images from the test set
TEST_IMAGE_DIR = 'USPictures/Test'
# Directory for preprocessed images
TRAIN_IMAGE_PREP_DIR = TRAIN_IMAGE_DIR + "/Processed"
TEST_IMAGE_PREP_DIR = TEST_IMAGE_DIR + "/Processed"
# Directory for the temporary output of the DeepFill model
DEPFILL_TEMP_DIR = 'USPictures/Deepfill'
# Excel file with the tabular data
CLINICAL_DATA_FILE = df
# Directory for saving the data dictionaries
OUTPUT_DIR = 'Output'
# File with the names of the images containing multiple US snapshots
BLACKLIST_FILE = 'multiple_in_one_'



# Directory Initialization
# Create directories if they do not exist
if not os.path.exists(TRAIN_IMAGE_DIR):
    os.makedirs(TRAIN_IMAGE_DIR)
if not os.path.exists(TEST_IMAGE_DIR):
    os.makedirs(TEST_IMAGE_DIR)

# %% [markdown]
# ## Collecting and Analyzing Ultrasound Image Data
#
# This script processes a directory of ultrasound images to gather insights into the dataset's composition regarding both the number of images and the distinct patients represented.
#
# ### Key Steps:
#
# - **Path Aggregation**: Gathers all image file paths with `.png` and `.bmp` extensions from the specified `IMAGE_DIR`.
# - **Patient Code Extraction**: For each image file, the script extracts a presumed patient code, which is the initial segment of the filename. This segment is expected to be a unique identifier for patients.
# - **Analysis Outputs**:
#   - Displays the total number of unique patients, which helps in understanding the dataset's diversity and patient coverage.
#   - Shows the total count of images, providing a basic metric of the dataset size.

# %%
# Assuming IMAGE_DIR is set to 'USPictures' which is relative to your current working directory
image_file_list = glob.glob(os.path.join(IMAGE_DIR, '*.png')) + glob.glob(os.path.join(IMAGE_DIR, '*.bmp'))

image_names = []
groups = []

for file in image_file_list:
    # Extract just the name of the file, without the preceding directory path
    name = os.path.basename(file)
    # Now split the name to extract the patient code
    patient_code = re.split('_| |\.', name)[0]
    groups.append(patient_code)

roups = np.array(list(map(int, groups)))
print("Total number of patients having US images: ", len(np.unique(groups)))
print("Total number of images: ", len(image_file_list))
# Out:
# Total number of patients having US images:  707
# Total number of images:  2095

# %% [markdown]
# ## Splitting Image Data into Training and Test Sets
#
# This section of the notebook handles the division of ultrasound image files into training and test sets based on the patient codes to ensure data integrity and prevent leakage between these sets.
#
# ### Procedure:
#
# - **List of Image Names**: Extracts just the filenames from the full paths, simplifying file handling in subsequent steps.
# - **Group Shuffle Split**:
#   - Utilizes `GroupShuffleSplit` to split image files into groups based on patient codes, maintaining approximately 90% of the data for training and 10% for testing. This ensures that all images from a single patient are in the same set.
#   - The split is controlled by a fixed random state to allow reproducibility of the results.
# - **File Copying**:
#   - Iterates over each image, and based on its determined index from the shuffle split, copies it to the appropriate directory (`TRAIN_IMAGE_DIR` for training and `TEST_IMAGE_DIR` for testing).
#   - Handles both `.png` and `.bmp` file formats, covering all the image data types present in the dataset.

# %%
# Populate image_names with just the file names
image_names = [os.path.basename(file) for file in image_file_list]

gss = GroupShuffleSplit(n_splits=1, train_size=.9, random_state=42)
for idx1, idx2 in gss.split(image_names, groups=groups):
    train_idx = idx1
    test_idx = idx2


for image_idx, image_name in enumerate(image_names):
    # Check if the image file is PNG or BMP
    if image_name.endswith('.png') or image_name.endswith('.bmp'):
        if image_idx in train_idx:
            copyfile(os.path.join(IMAGE_DIR, image_name), os.path.join(TRAIN_IMAGE_DIR, image_name))
        else:
            copyfile(os.path.join(IMAGE_DIR, image_name), os.path.join(TEST_IMAGE_DIR, image_name))

# %%
# Verify that patients in the splits do not overlap
pi.test_split(TRAIN_IMAGE_DIR, TEST_IMAGE_DIR)
# Out:
# Number of patients in train set:  636
# Number of patients in test set:  71
#
# Number of images in train set:  1907
# Number of images in test set:  188
#
# Patients in train and test set don't overlap!

# %%
# Directories to process
directories = [TRAIN_IMAGE_DIR, TEST_IMAGE_DIR]

# Apply the renaming function to each directory
for directory in directories:
    pi.rename_files_in_directory(directory)
# Out:
# File renaming complete in USPictures/Train.
# File renaming complete in USPictures/Test.

# %%
os.listdir(TRAIN_IMAGE_DIR)
# Out:
# ['1.1 RLQ_Pathological Lymphnodes.png',
#  '1.2 Ileitis.png',
#  '1.3 Mesenterial Lymphadenitis.png',
#  '1.4 Appendix.png',
#  '1.4_Appendix.png.png',
#  '1.5 Appendix, surrounding tissue reaction.png',
#  '10.1 Appendix and surrounding free fluis.png',
#  '10.2 Appendix and surrounding free fluis.png',
#  '100.1_App_M.png',
#  '100.2_RLQ.png',
#  '100.3_RLQ.png',
#  '101.10_App_M.png',
#  '101.11_App_M.png',
#  '101.12_App.png',
#  '101.13_App_M.png',
#  '101.14_App.png',
#  '101.15_App.png',
#  '101.1_App_M.png',
#  '101.2_App_D.png',
#  '101.3_App_M.png',
#  '101.4_App_M.png',
#  '101.5_App_M.png',
#  '101.6_App_M.png',
#  '101.7_App_M.png',
#  '101.8_App.png',
#  '101.9_App_M.png',
#  '102.10_App.png',
#  '102.11.png',
#  '102.12_App.png',
#  '102.13_App_M.png',
#  '102.14_App.png',
#  '102.15_App_M.png',
#  '102.16_App_M.png',
#  '102.17_App_M.png',
#  '102.18_App.png',
#  '102.19_App.png',
#  '102.1_App.png',
#  '102.2_App.png',
#  '102.3_App.png',
#  '102.4_App.png',
#  '102.5_App_M.png',
#  '102.6_App.png',
#  '102.7_App.png',
#  '102.8_App.png',
#  '102.9_App.png',
#  '103.1_App_M.png',
#  '103.2_App_M.png',
#  '103.3_App.png',
#  '103.4_App_M.png',
#  '103.5_App.png',
#  '103.6_App_M.png',
#  '103.7_App_M.png',
#  '103.8_App.png',
#  '103.9_App_M.png',
#  '104.1_RLQ_M.png',
#  '105.10_App.png',
#  '105.11_App_M.png',
#  '105.12_App.png',
#  '105.13_RLQ.png',
#  '105.1_App.png',
#  '105.2_App_M.png',
#  '105.3_App_M.png',
#  '105.4_App_M.png',
#  '105.5_App_M.png',
#  '105.6_App.png',
#  '105.7_App_M.png',
#  '105.8_App_M.png',
#  '105.9_App_M.png',
#  '106.1_App.png',
#  '106.2_App_M.png',
#  '106.3_App_M.png',
#  '106.4_App_M.png',
#  '106.5_App_M.png',
#  '106.6_App.png',
#  '106.7_App_M.png',
#  '106.8_App.png',
#  '107.1_App.png',
#  '107.2_App.png',
#  '107.3_App.png',
#  '107.4_App_M.png',
#  '107.5_App.png',
#  '109.1_App_M.png',
#  '109.2_App_M.png',
#  '109.3_App.png',
#  '11.1 Appendix.png',
#  '11.2 Enteritis.png',
#  '111.1_App_D.png',
#  '111.2_App_M.png',
#  '111.3_App.png',
#  '111.4_App_M.png',
#  '111.5_App_M.png',
#  '111.6_App.png',
#  '111.7_App_M.png',
#  '111.8_App_M.png',
#  '111.9_App_.png',
#  '112.1_RLQ.png',
#  '114.1_App_M.png',
#  '114.2_App_M.png',
#  '114.3_App.png',
#  '115.1_RLQ.png',
#  '116.1_App.png',
#  '116.2_App_M.png',
#  '195.5_App.png',
#  '195.6_App_M.png',
#  '197.1_App_M.png',
#  '198.1_App_M.png',
#  '198.2_App_M.png',
#  '198.3_App_D.png',
#  '198.4_App_D.png',
#  '198.5_App_D.png',
#  '20.1_Appendix_transv.png',
#  '20.2_Appendix_tangencial.png',
#  '201.2_App.png',
#  '202.1_App_M.png',
#  '202.2_App_M.png',
#  '202.3_App_M.png',
#  '202.4_App.png',
#  '203.1_App.png',
#  '203.2._App.png',
#  '204.1_RLQ.png',
#  '205.1_App_M.png',
#  '205.2_App_M.png',
#  '205.3_App_M.png',
#  '205.4_App.png',
#  '205.5_App_M.png',
#  '205.6_App_M.png',
#  '205.7_App_M.png',
#  '207.1_App_M.png',
#  '207.2_App_D.png',
#  '207.3_App.png',
#  '207.4_App.png',
#  '207.5_App.png',
#  '207.6_App.png',
#  '208.1_App_M.png',
#  '208.2_App_M.png',
#  '209.1_App_M.png',
#  '209.2_App_M.png',
#  '209.3_App_M.png',
#  '21.1_Free_fluids_Koller_Pouch.png',
#  '21.2_Appendix_long.png',
#  '210.1_App_M.png',
#  '210.2_App_M_.png',
#  '212.1_RLQ.png',
#  '213.1_App_M.png',
#  '215.1_App_M.png',
#  '215.2_App_M.png',
#  '216.1_App.png',
#  '216.2_App_M.png',
#  '216.3_App_M.png',
#  '216.4_App_M.png',
#  '216.5_App_M.png',
#  '22.1_RLQ_no_appendix_visible_in_this_pic.png',
#  '22.2_Appendix_long.png',
#  '22.3_Appendix_transv._target_sign.png',
#  '22.4_Free_fluids_perivesical.png',
#  '22.5_Appendix.png',
#  '220.1_App.png',
#  '220.2_App.png',
#  '220.3_App_M.png',
#  '221.1_RLQ.png',
#  '222.1_App_M.png',
#  '222.2_App_M.png',
#  '223.1_App_like_structure.png',
#  '224.1_App_M.png',
#  '224.2_App_M.png',
#  '224.3_App_M.png',
#  '225.1_App_M.png',
#  '225.2_App_M.png',
#  '227.1_RLQ.png',
#  '23.1_Appendix.png',
#  '23.2_Appendix.png',
#  '230.1_App_M.png',
#  '230.2_App_M.png',
#  '231.1_App.png',
#  '231.2_App.png',
#  '231.3_App.png',
#  '232.1_App_M.png',
#  '232.2_App.png',
#  '232.3_App.png',
#  '233.1_App_M.png',
#  '233.2_App_M.png',
#  '233.3_App.png',
#  '233.4_App.png',
#  '233.5_App.png',
#  '238.1_RLQ_App_not_visible.png',
#  '239.1_RLQ_app_not_visible.png',
#  '240.1_App.png',
#  '243.1_RLQ_app_not_visible.png',
#  '244.1_cockade,_appendix_like.png',
#  '248.1_RLQ.png',
#  '249.1_App.png',
#  '249.2_App.png',
#  '249.3_App.png',
#  '25.1_Appendix.png',
#  '25.2_Appendix.png',
#  '250.1_RLQ_app_not_visible.png',
#  '252.1_App_M.png',
#  '252.2_App.png',
#  '252.3_App_M.png',
#  '253.1_RLQ_app_not_visible.png',
#  '255.1_RLQ_app_not_visible.png',
#  '256.1_App_M.png',
#  '256.2_App_M.png',
#  '26.1_Appendix.png',
#  '26.2_Appendix.png',
#  '26.3_Appendix.png',
#  '264.1_RLQ.png',
#  '266.1_App_M.png',
#  '266.2_App.png',
#  '266.3_App.png',
#  '266.4_App_M.png',
#  '267.1_App_D.png',
#  '267.2_App_D.png',
#  '267.3_App_M.png',
#  '268.1_App_M.png',
#  '268.2_App_M.png',
#  '269.1_App_M.png',
#  '269.2_App_M.png',
#  '27.1_Lymphnodes_ileocolic.png',
#  '27.2_Appendix.png',
#  '270.1_App_M.png',
#  '270.2_App_M.png',
#  '270.3_App_M.png',
#  '270.4_App_M.png',
#  '271.1_App_M.png',
#  '271.2_App_M.png',
#  '271.3_App_M.png',
#  '271.4_App_M.png',
#  '271.5_App.png',
#  '271.6_App_M.png',
#  '272.1_RLQ_app_not_visible.png',
#  '274.1_RLQ_app_not_visible.png',
#  '275.1_RLQ_app_not_visible.png',
#  '276.1_App_M.png',
#  '276.2_App_M.png',
#  '276.3_App_M.png',
#  '277.1_App_M.png',
#  '277.2_App_M.png',
#  '277.3_App_M.png',
#  '277.4_App.png',
#  '277.5_App_M.png',
#  '278.1_App.png',
#  '278.2_App.png',
#  '278.3_App.png',
#  '279.1_RLQ_app_perforated.png',
#  '28.1_RLQ_no_appendix_visible_oin_this_pic,_adipositas.png',
#  '28.2_Appendix.png',
#  '280.1_RLQ_app_not_visible.png',
#  '282.1_App_M.png',
#  '282.2_App_M.png',
#  '282.3_App_M.png',
#  '282.4_App.png',
#  '283.1_App_M.png',
#  '284.1_App_M.png',
#  '284.2_App.png',
#  '285.1_App_M.png',
#  '285.2_App.png',
#  '285.3_App_M.png',
#  '285.4_App_M.png',
#  '285.5_App_M.png',
#  '285.6_App_M.png',
#  '287.1_RLQ_app_not_visible.png',
#  '288.1_App_M.png',
#  '288.2_App.png',
#  '288.3_app_perf.png',
#  '289.1_App.png',
#  '289.2_App.png',
#  '290.1_App_M.png',
#  '290.2_App.png',
#  '290.3_App.png',
#  '291.1_App_M.png',
#  '291.2_App_M.png',
#  '291.3_App_M.png',
#  '294.1_RLQ_app_not_visible.png',
#  '295.1_App_M.png',
#  '296.1_RLQ_app_not_visible.png',
#  '297.1_RLQ_app_not_visible.png',
#  '299.1_App.png',
#  '3.1 Appendix and surrounding tissue reaction.png',
#  '3.2 Appendix_target sign.png',
#  '3.3 Appendix.png',
#  '3.4 Appendix.png',
#  '3.5 Appendix.png',
#  '3.6 Mesenterial Lymphadenitis.png',
#  '30.1_LN_ileocolic.png',
#  '30.2_Appendix.png',
#  '30.3_Appendix.png',
#  '300.1_App_M.png',
#  '302.1_App_M.png',
#  '302.2_App_D.png',
#  '302.3_App_D.png',
#  '304.1_App_M.png',
#  '304.2_App.png',
#  '304.3_App.png',
#  '304.4_App_M.png',
#  '304.5_App_M.png',
#  '305.1_App_M.png',
#  '305.2_App_M.png',
#  '308.1_App_M.png',
#  '31.1_FF_perisplenic.png',
#  '31.2_FF_perihepatic.png',
#  '310.1_App_M.png',
#  '310.2_App_M.png',
#  '311.1_App_M.png',
#  '312.1_App_M.png',
#  '313.1_RLQ_app_not_visible.png',
#  '315.1_App.png',
#  '4.2 Appendix.png',
#  '401.1_App_M.png',
#  '403.1_RLQ_app_not_visible.png',
#  '405.1_RLQ_app_not_visible.png',
#  '408.1_RLQ_app_not_visible.png',
#  '41.1._App.png',
#  '41.2_App.png',
#  '41.3_App.png',
#  '41.4_App.png',
#  '411.1_RLQ_app_not_visible.png',
#  '415.1_RLQ_app_not_visible.png',
#  '417.1_App_M.png',
#  '419.1_RLQ_app_not_visible.png',
#  '42.1_Ileitis_Enteritis.png',
#  '42.2._Possibily_App.png',
#  '42.3_Possibily_App.png',
#  '42.4_Possibily_App.png',
#  '421.1_RLQ_app_not_visible.png',
#  '422.1_App.png',
#  '422.2_App_M.png',
#  '422.3_App_M.png',
#  '426.1_App_M_.png',
#  '429.1_RLQ_app_not_visible.png',
#  '430.1_RLQ_terminal_ileum.png',
#  '432.1_App_M.png',
#  '435.1_RLQ_app_not_visible.png',
#  '439.1_RLQ_ileum.png',
#  '44.1_App.png',
#  '44.2_Mesenterial_Lymphadenitis.png',
#  '441.1_App_M.png',
#  '441.2_App.png',
#  '441.3_App_.png',
#  '443.1_App.png',
#  '443.2_App.png',
#  '443.3_App.png',
#  '443.4_App.png',
#  '444.1_App_M.png',
#  '444.2_App_M.png',
#  '444.3_App_M.png',
#  '444.4_App.png',
#  '444.5_App_M.png',
#  '445.1_App_M.png',
#  '445.2_App.png',
#  '445.3_App.png',
#  '445.4_App.png',
#  '446.1_App.png',
#  '446.2_App.png',
#  '446.3_App_M.png',
#  '446.4_App_M.png',
#  '447.1_App_M.png',
#  '447.2_App_M.png',
#  '449.1_App.png',
#  '449.2_App_M.png',
#  '449.3_App.png',
#  '45.1_App_T.png',
#  '45.2_App_T.png',
#  '45.3_App_L.png',
#  '45.4_App_Color_doppler.png',
#  '45.5_App_T.png',
#  '450.1_RLQ_app_not_vis_.png',
#  '451.1_App_with_abscess.png',
#  '451.2_App_M_with_abscess.png',
#  '452.1_App_.png',
#  '453.1_App_M.png',
#  '453.2_App_D.png',
#  '455.1_App_perforated.png',
#  '455.2_App.png',
#  '456.1_RLQ_app_not_visible.png',
#  '457.1_App_M.png',
#  '457.2_App.png',
#  '458.1_App.png',
#  '458.2_App.png',
#  '458.3_App.png',
#  '458.4_App_M.png',
#  '458.5_App_M.png',
#  '458.6_App_D.png',
#  '458.7_App_D.png',
#  '458.8_App_M.png',
#  '458.9_App_M.png',
#  '459.1_App_M.png',
#  '459.2_App_M.png',
#  '46.1_Possibily_App_liver_lower_edge.png',
#  '460.1_RLQ_app_not_visible.png',
#  '461.1_RLQ_app_not_visible.png',
#  '462.1_App_M.png',
#  '462.2_App_M.png',
#  '463.1_App_M.png',
#  '463.2_App.png',
#  '463.3_App_M.png',
#  '463.4_App.png',
#  '463.5_App_M.png',
#  '463.6_App_M.png',
#  '464.1_App_D.png',
#  '464.2_App_M.png',
#  '464.3_App.png',
#  '465.1_App_D.png',
#  '465.2_App_D.png',
#  '465.3_App_D.png',
#  '465.4_App_M.png',
#  '465.5_App_M.png',
#  '465.6_App_M.png',
#  '547.8_App.png',
#  '547.9_App.png',
#  '548.1_App_M.png',
#  '55.1_LAM_RLQ.png',
#  '55.2_App.png',
#  '55.3_App.png',
#  '55.4_App_and_surr._FF.png',
#  '550.1_App.png',
#  '553.1_App.png',
#  '553.2_App_D.png',
#  '553.3_App_D.png',
#  '553.4_App_D.png',
#  '553.5_App_M.png',
#  '555.1_App_M.png',
#  '555.2_App.png',
#  '556.1_App_M.png',
#  '556.2_App_M.png',
#  '557.1_App.png',
#  '557.1_App_M.png',
#  '557.2_App_D.png',
#  '557.3_App.png',
#  '557.4_App_M.png',
#  '557.5_App_D.png',
#  '558.1_App_M.png',
#  '558.2_App.png',
#  '558.3_App_M.png',
#  '558.4_App_M.png',
#  '559.1_App_M.png',
#  '559.2_App_M.png',
#  '559.3_App.png',
#  '559.4_App_M.png',
#  '559.5_App_M.png',
#  '559.6_App_M.png',
#  '56.1_RLQ_min._FF_App_not_visible.png',
#  '56.2_App.png',
#  '560.1_App_M.png',
#  '560.2_App.png',
#  '560.3_App_M.png',
#  ...]

# %% [markdown]
# ## Image Preprocessing for Appendicitis Ultrasound Images
#
# This script is designed to automate the preprocessing of ultrasound images of appendicitis. The main goals are to identify and crop the relevant part of each image and to resize it to a standard dimension. This standardization is crucial for consistent analysis in subsequent processing steps such as feature extraction or machine learning modeling.
#
# ### Set Thresholds and Target Dimensions:
#    - `FOREGROUND_THRESHOLD`: This determines the minimum percentage of foreground pixels (pixels above a certain intensity) required for a row to be considered as containing relevant content.
#    - `SHADE_THRESHOLD`: This is the intensity above which a pixel is considered part of the foreground.
#    - `TARGET_DIMS`: The dimensions to which all images will be resized after cropping.

# %%
# Constants
FOREGROUND_THRESHOLD = 0.2
SHADE_THRESHOLD = 6
TARGET_DIMS = (400, 400)


# Directories to process
prep_images.process_images_in_directory(TRAIN_IMAGE_DIR, TRAIN_IMAGE_PREP_DIR, FOREGROUND_THRESHOLD, SHADE_THRESHOLD, TARGET_DIMS)
prep_images.process_images_in_directory(TEST_IMAGE_DIR, TEST_IMAGE_PREP_DIR, FOREGROUND_THRESHOLD, SHADE_THRESHOLD, TARGET_DIMS)
# Out:
# Processed images are saved in USPictures/Train/Processed
# Processed images are saved in USPictures/Test/Processed

# %%
CLINICAL_DATA_FILE = prep_images.preprocess_us_number(CLINICAL_DATA_FILE)
CLINICAL_DATA_FILE = prep_images.convert_column_to_string(CLINICAL_DATA_FILE, 'US_Number')
# Out:
# c:\Users\Benedict\Desktop\Business Analytics and Econometrics\SS24\Seminar\MLSEM\7. US_Pictures\lib\prep_images.py:183: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[us_number_col] = df[us_number_col].astype(int)
# c:\Users\Benedict\Desktop\Business Analytics and Econometrics\SS24\Seminar\MLSEM\7. US_Pictures\lib\prep_images.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[column_name].astype(str)

# %%
CLINICAL_DATA_FILE.loc[CLINICAL_DATA_FILE['US_Number'] == '662']
# Out:
# Empty DataFrame
# Columns: [Age, BMI, Sex, Height, Weight, Length_of_Stay, Management, Severity, Diagnosis_Presumptive, Diagnosis, Alvarado_Score, Paedriatic_Appendicitis_Score, Appendix_on_US, Appendix_Diameter, Migratory_Pain, Lower_Right_Abd_Pain, Contralateral_Rebound_Tenderness, Coughing_Pain, Nausea, Loss_of_Appetite, Body_Temperature, WBC_Count, Neutrophil_Percentage, Segmented_Neutrophils, Neutrophilia, RBC_Count, Hemoglobin, RDW, Thrombocyte_Count, Ketones_in_Urine, RBC_in_Urine, WBC_in_Urine, CRP, Dysuria, Stool, Peritonitis, Psoas_Sign, Ipsilateral_Rebound_Tenderness, US_Performed, US_Number, Free_Fluids, Appendix_Wall_Layers, Target_Sign, Appendicolith, Perfusion, Perforation, Surrounding_Tissue_Reaction, Appendicular_Abscess, Abscess_Location, Pathological_Lymph_Nodes, Lymph_Nodes_Location, Bowel_Wall_Thickening, Conglomerate_of_Bowel_Loops, Ileus, Coprostasis, Meteorism, Enteritis, Gynecological_Findings, Unnamed: 58, Unnamed: 59, Unnamed: 60, Unnamed: 61, Unnamed: 62, Unnamed: 63, Unnamed: 64, Unnamed: 65, Unnamed: 66, Unnamed: 67, Unnamed: 68]
# Index: []

# %%
prep_images.process_images_and_create_csv(TRAIN_IMAGE_PREP_DIR, CLINICAL_DATA_FILE)
prep_images.process_images_and_create_csv(TEST_IMAGE_PREP_DIR, CLINICAL_DATA_FILE)
print(f"Missing US_Number entries in TRAIN: {prep_images.missing_counts['train']}")
print(f"Missing US_Number entries in TEST: {prep_images.missing_counts['test']}")
# Out:
# US_Number 102 not found in DataFrame.
# US_Number 102 not found in DataFrame.
# US_Number 102 not found in DataFrame.
# US_Number 102 not found in DataFrame.
# US_Number 102 not found in DataFrame.
# US_Number 102 not found in DataFrame.
# US_Number 102 not found in DataFrame.
# US_Number 102 not found in DataFrame.
# US_Number 102 not found in DataFrame.
# US_Number 102 not found in DataFrame.
# US_Number 102 not found in DataFrame.
# US_Number 102 not found in DataFrame.
# US_Number 102 not found in DataFrame.
# US_Number 102 not found in DataFrame.
# US_Number 102 not found in DataFrame.
# US_Number 102 not found in DataFrame.
# US_Number 102 not found in DataFrame.
# US_Number 102 not found in DataFrame.
# US_Number 102 not found in DataFrame.
# US_Number 22 not found in DataFrame.
# US_Number 22 not found in DataFrame.
# US_Number 22 not found in DataFrame.
# US_Number 22 not found in DataFrame.
# US_Number 22 not found in DataFrame.
# US_Number 23 not found in DataFrame.
# US_Number 23 not found in DataFrame.
# US_Number 230 not found in DataFrame.
# US_Number 230 not found in DataFrame.
# US_Number 248 not found in DataFrame.
# US_Number 277 not found in DataFrame.
# US_Number 277 not found in DataFrame.
# US_Number 277 not found in DataFrame.
# US_Number 277 not found in DataFrame.
# US_Number 277 not found in DataFrame.
# US_Number 296 not found in DataFrame.
# US_Number 311 not found in DataFrame.
# US_Number 389 not found in DataFrame.
# US_Number 389 not found in DataFrame.
# US_Number 391 not found in DataFrame.
# US_Number 391 not found in DataFrame.
# US_Number 391 not found in DataFrame.
# US_Number 53 not found in DataFrame.
# US_Number 53 not found in DataFrame.
# US_Number 53 not found in DataFrame.
# US_Number 53 not found in DataFrame.
# US_Number 885 not found in DataFrame.
# US_Number 899 not found in DataFrame.
# US_Number 906 not found in DataFrame.
# US_Number 907 not found in DataFrame.
# US_Number 908 not found in DataFrame.
# US_Number 908 not found in DataFrame.
# US_Number 908 not found in DataFrame.
# US_Number 908 not found in DataFrame.
# US_Number 912 not found in DataFrame.
# US_Number 919 not found in DataFrame.
# US_Number 919 not found in DataFrame.
# US_Number 919 not found in DataFrame.
# US_Number 937 not found in DataFrame.
# US_Number 94 not found in DataFrame.
# US_Number 94 not found in DataFrame.
# US_Number 94 not found in DataFrame.
# US_Number 94 not found in DataFrame.
# US_Number 94 not found in DataFrame.
# US_Number 94 not found in DataFrame.
# US_Number 94 not found in DataFrame.
# US_Number 94 not found in DataFrame.
# US_Number 94 not found in DataFrame.
# US_Number 94 not found in DataFrame.
# US_Number 94 not found in DataFrame.
# US_Number 94 not found in DataFrame.
# US_Number 941 not found in DataFrame.
# US_Number 944 not found in DataFrame.
# US_Number 944 not found in DataFrame.
# US_Number 960 not found in DataFrame.
# US_Number 972 not found in DataFrame.
# US_Number 979 not found in DataFrame.
# US_Number 980 not found in DataFrame.
# US_Number 985 not found in DataFrame.
# US_Number 985 not found in DataFrame.
# US_Number 985 not found in DataFrame.
# US_Number 985 not found in DataFrame.
# US_Number 985 not found in DataFrame.
# US_Number 990 not found in DataFrame.
# US_Number 990 not found in DataFrame.
# US_Number 990 not found in DataFrame.
# US_Number 990 not found in DataFrame.
# US_Number 990 not found in DataFrame.
# US_Number 990 not found in DataFrame.
# US_Number 990 not found in DataFrame.
# US_Number 990 not found in DataFrame.
# US_Number 990 not found in DataFrame.
# CSV file updated: image_labels.csv
# Deleted unlabeled image: USPictures\Train\Processed\102.10_App.png
# Deleted unlabeled image: USPictures\Train\Processed\102.11.png
# Deleted unlabeled image: USPictures\Train\Processed\102.12_App.png
# Deleted unlabeled image: USPictures\Train\Processed\102.13_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\102.14_App.png
# Deleted unlabeled image: USPictures\Train\Processed\102.15_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\102.16_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\102.17_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\102.18_App.png
# Deleted unlabeled image: USPictures\Train\Processed\102.19_App.png
# Deleted unlabeled image: USPictures\Train\Processed\102.1_App.png
# Deleted unlabeled image: USPictures\Train\Processed\102.2_App.png
# Deleted unlabeled image: USPictures\Train\Processed\102.3_App.png
# Deleted unlabeled image: USPictures\Train\Processed\102.4_App.png
# Deleted unlabeled image: USPictures\Train\Processed\102.5_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\102.6_App.png
# Deleted unlabeled image: USPictures\Train\Processed\102.7_App.png
# Deleted unlabeled image: USPictures\Train\Processed\102.8_App.png
# Deleted unlabeled image: USPictures\Train\Processed\102.9_App.png
# Deleted unlabeled image: USPictures\Train\Processed\22.1_RLQ_no_appendix_visible_in_this_pic.png
# Deleted unlabeled image: USPictures\Train\Processed\22.2_Appendix_long.png
# Deleted unlabeled image: USPictures\Train\Processed\22.3_Appendix_transv._target_sign.png
# Deleted unlabeled image: USPictures\Train\Processed\22.4_Free_fluids_perivesical.png
# Deleted unlabeled image: USPictures\Train\Processed\22.5_Appendix.png
# Deleted unlabeled image: USPictures\Train\Processed\23.1_Appendix.png
# Deleted unlabeled image: USPictures\Train\Processed\23.2_Appendix.png
# Deleted unlabeled image: USPictures\Train\Processed\230.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\230.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\248.1_RLQ.png
# Deleted unlabeled image: USPictures\Train\Processed\277.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\277.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\277.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\277.4_App.png
# Deleted unlabeled image: USPictures\Train\Processed\277.5_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\296.1_RLQ_app_not_visible.png
# Deleted unlabeled image: USPictures\Train\Processed\311.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\389.1_App.png
# Deleted unlabeled image: USPictures\Train\Processed\389.2_App_.png
# Deleted unlabeled image: USPictures\Train\Processed\391.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\391.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\391.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\53.1_App_L_and_surr._tissue_reaction.png
# Deleted unlabeled image: USPictures\Train\Processed\53.2_App.png
# Deleted unlabeled image: USPictures\Train\Processed\53.3_FF_perivesical.png
# Deleted unlabeled image: USPictures\Train\Processed\53.4_App_L.png
# Deleted unlabeled image: USPictures\Train\Processed\53.5_App_T.png
# Deleted unlabeled image: USPictures\Train\Processed\541.1_App.png
# Deleted unlabeled image: USPictures\Train\Processed\541.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\576.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\576.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\576.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\582.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\582.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\59.1_LAM_RLQ.png
# Deleted unlabeled image: USPictures\Train\Processed\59.2_App.png
# Deleted unlabeled image: USPictures\Train\Processed\594.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\594.2_App.png
# Deleted unlabeled image: USPictures\Train\Processed\594.3_App.png
# Deleted unlabeled image: USPictures\Train\Processed\608.1_RLQ.png
# Deleted unlabeled image: USPictures\Train\Processed\618.1_RLQ.png
# Deleted unlabeled image: USPictures\Train\Processed\618.2_RLQ_M.png
# Deleted unlabeled image: USPictures\Train\Processed\627.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\632.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\632.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\632.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\649.1_RLQ.png
# Deleted unlabeled image: USPictures\Train\Processed\650.1_RLQ_app_not_found.png
# Deleted unlabeled image: USPictures\Train\Processed\662.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\662.2_App_D.png
# Deleted unlabeled image: USPictures\Train\Processed\662.3_App_D.png
# Deleted unlabeled image: USPictures\Train\Processed\662.4_App_D.png
# Deleted unlabeled image: USPictures\Train\Processed\662.5_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\666.1_App_lymphoma.png
# Deleted unlabeled image: USPictures\Train\Processed\666.2_App_lymphoma.png
# Deleted unlabeled image: USPictures\Train\Processed\669.1_RLQ.png
# Deleted unlabeled image: USPictures\Train\Processed\673.1_App.png
# Deleted unlabeled image: USPictures\Train\Processed\673.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\673.3_App_D.png
# Deleted unlabeled image: USPictures\Train\Processed\676.1_RLQ.png
# Deleted unlabeled image: USPictures\Train\Processed\677.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\677.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\677.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\678.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\678.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\679.1_RLQ.png
# Deleted unlabeled image: USPictures\Train\Processed\680.1_RLQ_app_not_visible.png
# Deleted unlabeled image: USPictures\Train\Processed\684.1_App_M_text.png
# Deleted unlabeled image: USPictures\Train\Processed\684.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\692.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\692.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\692.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\694.1_RLQ.png
# Deleted unlabeled image: USPictures\Train\Processed\713.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\713.2_App_D.png
# Deleted unlabeled image: USPictures\Train\Processed\713.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\719.1_RLQ_app_not_vis.png
# Deleted unlabeled image: USPictures\Train\Processed\726.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\729.1_RLQ_app_not_vis.png
# Deleted unlabeled image: USPictures\Train\Processed\741.1_RLQ_app_not_vis.png
# Deleted unlabeled image: USPictures\Train\Processed\742.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\742.2_App.png
# Deleted unlabeled image: USPictures\Train\Processed\747.10_App.png
# Deleted unlabeled image: USPictures\Train\Processed\747.11_App.png
# Deleted unlabeled image: USPictures\Train\Processed\747.12_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\747.13_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\747.1_App.png
# Deleted unlabeled image: USPictures\Train\Processed\747.2_App.png
# Deleted unlabeled image: USPictures\Train\Processed\747.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\747.4_App.png
# Deleted unlabeled image: USPictures\Train\Processed\747.5_App.png
# Deleted unlabeled image: USPictures\Train\Processed\747.6_App.png
# Deleted unlabeled image: USPictures\Train\Processed\747.7_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\747.8_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\747.9_App.png
# Deleted unlabeled image: USPictures\Train\Processed\767.1_App.png
# Deleted unlabeled image: USPictures\Train\Processed\767.2_App_D.png
# Deleted unlabeled image: USPictures\Train\Processed\767.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\767.4_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\773.10_App.png
# Deleted unlabeled image: USPictures\Train\Processed\773.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\773.2_App.png
# Deleted unlabeled image: USPictures\Train\Processed\773.3_App.png
# Deleted unlabeled image: USPictures\Train\Processed\773.4_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\773.5_App.png
# Deleted unlabeled image: USPictures\Train\Processed\773.6_App.png
# Deleted unlabeled image: USPictures\Train\Processed\773.7_App.png
# Deleted unlabeled image: USPictures\Train\Processed\773.8_App.png
# Deleted unlabeled image: USPictures\Train\Processed\773.9_App.png
# Deleted unlabeled image: USPictures\Train\Processed\784.1_RLQ_enteritis.png
# Deleted unlabeled image: USPictures\Train\Processed\785.1_RLQ_app_not_vis.png
# Deleted unlabeled image: USPictures\Train\Processed\792.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\792.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\792.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\792.4_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\809.1_App.png
# Deleted unlabeled image: USPictures\Train\Processed\809.2_App.png
# Deleted unlabeled image: USPictures\Train\Processed\809.3_App.png
# Deleted unlabeled image: USPictures\Train\Processed\812.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\812.2_App_D.png
# Deleted unlabeled image: USPictures\Train\Processed\813.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\813.2_App_D.png
# Deleted unlabeled image: USPictures\Train\Processed\813.3_App_D.png
# Deleted unlabeled image: USPictures\Train\Processed\813.4_App.png
# Deleted unlabeled image: USPictures\Train\Processed\814.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\814.2_App.png
# Deleted unlabeled image: USPictures\Train\Processed\814.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\814.4_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\814.5_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\814.6_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\814.7_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\815.1_App-perforated.png
# Deleted unlabeled image: USPictures\Train\Processed\815.2_RLQ.png
# Deleted unlabeled image: USPictures\Train\Processed\816.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\816.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\816.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\816.4_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\816.5_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\816.6_App.png
# Deleted unlabeled image: USPictures\Train\Processed\816.7_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\816.8_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\817.1_RLQ_app_not_vis.png
# Deleted unlabeled image: USPictures\Train\Processed\818.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\818.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\818.3_App_D.png
# Deleted unlabeled image: USPictures\Train\Processed\819.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\819.2_App.png
# Deleted unlabeled image: USPictures\Train\Processed\819.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\820.1_App_D.png
# Deleted unlabeled image: USPictures\Train\Processed\820.2_App_D.png
# Deleted unlabeled image: USPictures\Train\Processed\824.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\824.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\824.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\824.4_App.png
# Deleted unlabeled image: USPictures\Train\Processed\824.5_App.png
# Deleted unlabeled image: USPictures\Train\Processed\824.6_App.png
# Deleted unlabeled image: USPictures\Train\Processed\824.7_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\825.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\825.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\825.3_App_D.png
# Deleted unlabeled image: USPictures\Train\Processed\826.1_App.png
# Deleted unlabeled image: USPictures\Train\Processed\826.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\827.1_App.png
# Deleted unlabeled image: USPictures\Train\Processed\827.2_App.png
# Deleted unlabeled image: USPictures\Train\Processed\827.3_App.png
# Deleted unlabeled image: USPictures\Train\Processed\827.4_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\827.5_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\829.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\831.1_App.png
# Deleted unlabeled image: USPictures\Train\Processed\831.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\831.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\831.4_App.png
# Deleted unlabeled image: USPictures\Train\Processed\831.5_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\831.6_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\832.1_App.png
# Deleted unlabeled image: USPictures\Train\Processed\832.2_App.png
# Deleted unlabeled image: USPictures\Train\Processed\832.3_App.png
# Deleted unlabeled image: USPictures\Train\Processed\832.4_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\833.1_RLQ.png
# Deleted unlabeled image: USPictures\Train\Processed\833.2_App.png
# Deleted unlabeled image: USPictures\Train\Processed\833.3_App.png
# Deleted unlabeled image: USPictures\Train\Processed\833.4_App.png
# Deleted unlabeled image: USPictures\Train\Processed\833.5_App.png
# Deleted unlabeled image: USPictures\Train\Processed\833.6_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\833.7_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\834.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\835.1_App_D.png
# Deleted unlabeled image: USPictures\Train\Processed\835.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\836.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\836.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\836.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\836.4_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\837.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\837.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\837.3_App.png
# Deleted unlabeled image: USPictures\Train\Processed\837.4_App.png
# Deleted unlabeled image: USPictures\Train\Processed\837.5_App.png
# Deleted unlabeled image: USPictures\Train\Processed\837.6_App.png
# Deleted unlabeled image: USPictures\Train\Processed\837.7_App.png
# Deleted unlabeled image: USPictures\Train\Processed\838.1_App.png
# Deleted unlabeled image: USPictures\Train\Processed\838.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\838.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\839.1_RLQ.png
# Deleted unlabeled image: USPictures\Train\Processed\840.1_App.png
# Deleted unlabeled image: USPictures\Train\Processed\840.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\841.1_App.png
# Deleted unlabeled image: USPictures\Train\Processed\841.2_App.png
# Deleted unlabeled image: USPictures\Train\Processed\841.3_App.png
# Deleted unlabeled image: USPictures\Train\Processed\841.4_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\841.5_App.png
# Deleted unlabeled image: USPictures\Train\Processed\841.6_App.png
# Deleted unlabeled image: USPictures\Train\Processed\843.1_App_perforated_appendix_wit_coprolith.png
# Deleted unlabeled image: USPictures\Train\Processed\845.1_App_perforated_Appendix_with_tissue_reaction.png
# Deleted unlabeled image: USPictures\Train\Processed\846.1_App.png
# Deleted unlabeled image: USPictures\Train\Processed\847.1_App_D.png
# Deleted unlabeled image: USPictures\Train\Processed\847.2_App_D.png
# Deleted unlabeled image: USPictures\Train\Processed\847.3_App.png
# Deleted unlabeled image: USPictures\Train\Processed\847.4_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\847.5_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\849.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\849.2_App.png
# Deleted unlabeled image: USPictures\Train\Processed\849.3_App.png
# Deleted unlabeled image: USPictures\Train\Processed\849.4_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\849.5_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\850.1_App.png
# Deleted unlabeled image: USPictures\Train\Processed\850.2_App.png
# Deleted unlabeled image: USPictures\Train\Processed\850.3_App_D.png
# Deleted unlabeled image: USPictures\Train\Processed\851.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\851.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\851.3_Appendicolith.png
# Deleted unlabeled image: USPictures\Train\Processed\852.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\853.1_App.png
# Deleted unlabeled image: USPictures\Train\Processed\853.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\853.3_App.png
# Deleted unlabeled image: USPictures\Train\Processed\853.4_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\854.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\854.2_App.png
# Deleted unlabeled image: USPictures\Train\Processed\855.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\855.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\856.1_App.png
# Deleted unlabeled image: USPictures\Train\Processed\858.1_cocarde.png
# Deleted unlabeled image: USPictures\Train\Processed\858.2_perforated_app.png
# Deleted unlabeled image: USPictures\Train\Processed\858.3_perforated_app.png
# Deleted unlabeled image: USPictures\Train\Processed\861.1_RLQ_invagination.png
# Deleted unlabeled image: USPictures\Train\Processed\861.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\861.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\861.4_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\862.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\862.2_App.png
# Deleted unlabeled image: USPictures\Train\Processed\863.1_App.png
# Deleted unlabeled image: USPictures\Train\Processed\863.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\863.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\863.4_App.png
# Deleted unlabeled image: USPictures\Train\Processed\864.1_App_D.png
# Deleted unlabeled image: USPictures\Train\Processed\864.2_App_D.png
# Deleted unlabeled image: USPictures\Train\Processed\867.1_RLQ_perforated_app_not_vis.png
# Deleted unlabeled image: USPictures\Train\Processed\871.1_App.png
# Deleted unlabeled image: USPictures\Train\Processed\871.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\871.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\871.4_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\872.1_App.png
# Deleted unlabeled image: USPictures\Train\Processed\872.2_App.png
# Deleted unlabeled image: USPictures\Train\Processed\872.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\872.4_App.png
# Deleted unlabeled image: USPictures\Train\Processed\874.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\874.2_App.png
# Deleted unlabeled image: USPictures\Train\Processed\874.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\875.1_App.png
# Deleted unlabeled image: USPictures\Train\Processed\875.2_App_D.png
# Deleted unlabeled image: USPictures\Train\Processed\875.3_App_D.png
# Deleted unlabeled image: USPictures\Train\Processed\876.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\876.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\876.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\878.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\878.2_App_D.png
# Deleted unlabeled image: USPictures\Train\Processed\879.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\879.2_App.png
# Deleted unlabeled image: USPictures\Train\Processed\879.3_App.png
# Deleted unlabeled image: USPictures\Train\Processed\880.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\881.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\881.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\881.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\881.4_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\885.1_RLQ_app_not_vis.png
# Deleted unlabeled image: USPictures\Train\Processed\899.1_RLQ_app_not_vis.png
# Deleted unlabeled image: USPictures\Train\Processed\906.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\907.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\908.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\908.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\908.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\908.4_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\912.1_ileoileal_invagination.png
# Deleted unlabeled image: USPictures\Train\Processed\919.1_RLQ.png
# Deleted unlabeled image: USPictures\Train\Processed\919.2_App.png
# Deleted unlabeled image: USPictures\Train\Processed\919.3_App.png
# Deleted unlabeled image: USPictures\Train\Processed\937.1_RLQ_app_not_vis.png
# Deleted unlabeled image: USPictures\Train\Processed\94.10_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\94.11_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\94.12_RLQ.png
# Deleted unlabeled image: USPictures\Train\Processed\94.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\94.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\94.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\94.4_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\94.5_App.png
# Deleted unlabeled image: USPictures\Train\Processed\94.6_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\94.7_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\94.8_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\94.9_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\941.1_RLQ_app_not_vis.png
# Deleted unlabeled image: USPictures\Train\Processed\944.1_paracolic_invagination.png
# Deleted unlabeled image: USPictures\Train\Processed\944.2_invagination.png
# Deleted unlabeled image: USPictures\Train\Processed\960.1_RLQ_app_not_vis.png
# Deleted unlabeled image: USPictures\Train\Processed\972.1_RLQ_app_not_vis.png
# Deleted unlabeled image: USPictures\Train\Processed\979.1_RLQ_app_not_vis.png
# Deleted unlabeled image: USPictures\Train\Processed\980.1_RLQ_app_not_vis.png
# Deleted unlabeled image: USPictures\Train\Processed\985.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\985.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\985.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\985.4_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\985.5_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\990.1_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\990.2_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\990.3_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\990.4_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\990.5_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\990.6_App_M.png
# Deleted unlabeled image: USPictures\Train\Processed\990.7_App.png
# Deleted unlabeled image: USPictures\Train\Processed\990.8_App.png
# Deleted unlabeled image: USPictures\Train\Processed\990.9_App.png
# Total missing US_Number in Processed: 348
# US_Number 574 not found in DataFrame.
# US_Number 574 not found in DataFrame.
# US_Number 574 not found in DataFrame.
# US_Number 630 not found in DataFrame.
# US_Number 630 not found in DataFrame.
# US_Number 630 not found in DataFrame.
# US_Number 76 not found in DataFrame.
# US_Number 76 not found in DataFrame.
# US_Number 76 not found in DataFrame.
# US_Number 76 not found in DataFrame.
# US_Number 762 not found in DataFrame.
# US_Number 762 not found in DataFrame.
# US_Number 798 not found in DataFrame.
# US_Number 811 not found in DataFrame.
# US_Number 844 not found in DataFrame.
# US_Number 848 not found in DataFrame.
# US_Number 848 not found in DataFrame.
# US_Number 870 not found in DataFrame.
# US_Number 870 not found in DataFrame.
# US_Number 873 not found in DataFrame.
# US_Number 915 not found in DataFrame.
# CSV file updated: image_labels.csv
# Deleted unlabeled image: USPictures\Test\Processed\574.1_App_M.png
# Deleted unlabeled image: USPictures\Test\Processed\574.2_App_M.png
# Deleted unlabeled image: USPictures\Test\Processed\574.3_App_M.png
# Deleted unlabeled image: USPictures\Test\Processed\630.1_App_M.png
# Deleted unlabeled image: USPictures\Test\Processed\630.2_App_M.png
# Deleted unlabeled image: USPictures\Test\Processed\630.3_App_M.png
# Deleted unlabeled image: USPictures\Test\Processed\76.1_App_T.png
# Deleted unlabeled image: USPictures\Test\Processed\76.2_App_T.png
# Deleted unlabeled image: USPictures\Test\Processed\76.3_App_L.png
# Deleted unlabeled image: USPictures\Test\Processed\76.4_App_L.png
# Deleted unlabeled image: USPictures\Test\Processed\762.1_RLQ_appendicitis.png
# Deleted unlabeled image: USPictures\Test\Processed\762.2_RLQ_appendicitis.png
# Deleted unlabeled image: USPictures\Test\Processed\798.1_RLQ_app_not_vis.png
# Deleted unlabeled image: USPictures\Test\Processed\811.1_App_M.png
# Deleted unlabeled image: USPictures\Test\Processed\844.1_RLQ_app_not_vis.png
# Deleted unlabeled image: USPictures\Test\Processed\848.1_App_M.png
# Deleted unlabeled image: USPictures\Test\Processed\848.2_App_D.png
# Deleted unlabeled image: USPictures\Test\Processed\870.1_App_M.png
# Deleted unlabeled image: USPictures\Test\Processed\870.2_RLQ_perforated_app_not_vis.png
# Deleted unlabeled image: USPictures\Test\Processed\873.1_App_perforated_with_tissue_reaction.png
# Deleted unlabeled image: USPictures\Test\Processed\915.1_RLQ_app_not_vis.png
# Total missing US_Number in Processed: 21
# Missing US_Number entries in TRAIN: 348
# Missing US_Number entries in TEST: 21

# %% [markdown]
# # CNN

# %% [markdown]
# #### Multview Approach,  still on Progress

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from pathlib import Path
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight
import cv2

def preprocess_image(image_array):
    if image_array.ndim == 3 and image_array.shape[2] == 3:
        image_array = cv2.cvtColor(image_array, cv2.COLOR_BGR2GRAY)
    elif image_array.ndim == 3 and image_array.shape[2] == 4:
        image_array = cv2.cvtColor(image_array, cv2.COLOR_BGRA2GRAY)
    if image_array.dtype != np.uint8:
        image_array = (255 * image_array).astype(np.uint8)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    image_array = clahe.apply(image_array)
    image_array = cv2.medianBlur(image_array, 5)
    return image_array.astype(np.float32) / 255.0

def extract_patient_id(filename):
    return filename.split('.')[0]

def load_data(image_dir, label_file, target_size=(128, 128), max_sequence_length=15):
    df = pd.read_csv(label_file, header=None, names=['filename', 'label', 'complication', 'treatment'])
    df['patient_id'] = df['filename'].apply(lambda filename: filename.split('.')[0])  # Extract patient ID from filename

    grouped = df.groupby('patient_id')

    sequences = []
    labels = []
    all_filenames = []  # To store filenames for each sequence for the DataFrame

    for patient_id, group in grouped:
        images = []
        filenames = []  # To track filenames for the current sequence
        for idx, row in group.iterrows():
            img_path = Path(image_dir) / row['filename']
            if img_path.exists():
                img = tf.keras.preprocessing.image.load_img(img_path, color_mode='rgb', target_size=target_size)
                img_array = tf.keras.preprocessing.image.img_to_array(img)
                processed_image = preprocess_image(img_array)
                processed_image = np.expand_dims(processed_image, axis=-1)  # Ensure image has channel dimension
                if processed_image is not None:
                    images.append(processed_image)
                    filenames.append(row['filename'])  # Track filename

        if images:
            # Pad or truncate the list of images to ensure consistent length
            images = images[:max_sequence_length]  # Truncate if longer
            if len(images) < max_sequence_length:
                # Pad with zero arrays if shorter
                padding = [np.zeros((target_size[0], target_size[1], 1)) for _ in range(max_sequence_length - len(images))]
                images.extend(padding)
                filenames.extend([''] * (max_sequence_length - len(filenames)))  # Pad filenames with empty strings

            sequences.append(np.stack(images))  # Stack images to create a single array per patient
            labels.append(group['label'].iloc[0])  # Assume all images per patient have the same label
            all_filenames.append(filenames)  # Append list of filenames for this sequence

    # Convert labels to one-hot encoding
    labels = pd.get_dummies(labels).values

    # Create DataFrame to track filenames and labels
    data_df = pd.DataFrame({
        'Filename': [item for sublist in all_filenames for item in sublist],  # Flatten list of filenames
        'Label': np.repeat(labels.argmax(axis=1), max_sequence_length)  # Repeat labels for each image in sequence
    })

    return np.array(sequences), labels, data_df

# Example usage
train_images, train_labels, train_df = load_data(TRAIN_IMAGE_DIR, 'image_labels.csv')
test_images, test_labels, test_df = load_data(TEST_IMAGE_DIR, 'image_labels.csv')

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

def create_3d_cnn_model(input_shape, num_classes):
    model = models.Sequential()
    
    # 3D Convolutional layers
    model.add(layers.Conv3D(32, kernel_size=(3, 3, 3), activation='relu', padding='same', input_shape=input_shape))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling3D(pool_size=(2, 2, 2)))
    model.add(layers.Conv3D(64, kernel_size=(3, 3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling3D(pool_size=(2, 2, 2)))
    model.add(layers.Conv3D(128, kernel_size=(3, 3, 3), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling3D(pool_size=(2, 2, 2)))

    # Flatten and Dense layers to perform final classification
    model.add(layers.Flatten())
    model.add(layers.Dense(256, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(num_classes, activation='softmax'))
    
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Assuming that `train_images` and `test_images` have the shape [samples, sequence_length, width, height, channels]
# If train_images are not in the correct shape, you will need to reshape them accordingly
input_shape = train_images.shape[1:]  # This assumes train_images is already in the correct shape
num_classes = train_labels.shape[1]  # Assuming train_labels are one-hot encoded

model = create_3d_cnn_model(input_shape, num_classes)
# Out:
# C:\Users\Benedict\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Train the model
history = model.fit(
    train_images, train_labels,
    validation_split=0.2,  # Using part of the training data as validation
    epochs=100,
    callbacks=[early_stopping]
)

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test Accuracy: {test_acc}")
# Out:
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 60s 4s/step - accuracy: 0.5957 - loss: 24.2836 - val_accuracy: 0.7404 - val_loss: 0.7671
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 57s 4s/step - accuracy: 0.5795 - loss: 9.0237 - val_accuracy: 0.5673 - val_loss: 2.7584
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 53s 4s/step - accuracy: 0.6916 - loss: 5.0448 - val_accuracy: 0.5192 - val_loss: 2.5208
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 53s 4s/step - accuracy: 0.6616 - loss: 2.5892 - val_accuracy: 0.4519 - val_loss: 3.8010
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - accuracy: 0.5713 - loss: 1.0964 - val_accuracy: 0.5096 - val_loss: 3.2618
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 52s 4s/step - accuracy: 0.6858 - loss: 0.7722 - val_accuracy: 0.5577 - val_loss: 2.0127
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 52s 4s/step - accuracy: 0.5784 - loss: 0.7575 - val_accuracy: 0.5962 - val_loss: 2.5166
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 52s 4s/step - accuracy: 0.6857 - loss: 0.6443 - val_accuracy: 0.6058 - val_loss: 3.3187
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 52s 4s/step - accuracy: 0.6809 - loss: 0.5793 - val_accuracy: 0.5962 - val_loss: 4.2361
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 52s 4s/step - accuracy: 0.6711 - loss: 0.6348 - val_accuracy: 0.6058 - val_loss: 2.8964
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 52s 4s/step - accuracy: 0.7077 - loss: 0.6230 - val_accuracy: 0.5962 - val_loss: 3.1740
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 52s 4s/step - accuracy: 0.6637 - loss: 0.6359 - val_accuracy: 0.5962 - val_loss: 3.7116
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 53s 4s/step - accuracy: 0.6383 - loss: 0.7237 - val_accuracy: 0.5962 - val_loss: 5.0119
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 52s 4s/step - accuracy: 0.6697 - loss: 0.6861 - val_accuracy: 0.5962 - val_loss: 7.8189
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.6962 - loss: 0.6627 - val_accuracy: 0.5962 - val_loss: 9.9362
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.6436 - loss: 0.6243 - val_accuracy: 0.5962 - val_loss: 10.5099
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.6715 - loss: 0.8153 - val_accuracy: 0.5962 - val_loss: 12.2198
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 52s 4s/step - accuracy: 0.6931 - loss: 0.6700 - val_accuracy: 0.5962 - val_loss: 22.1040
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 52s 4s/step - accuracy: 0.6890 - loss: 1.0472 - val_accuracy: 0.5962 - val_loss: 23.3515
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.6876 - loss: 0.9786 - val_accuracy: 0.5962 - val_loss: 24.1477
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 52s 4s/step - accuracy: 0.6898 - loss: 0.8267 - val_accuracy: 0.5962 - val_loss: 20.0673
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step - accuracy: 0.5812 - loss: 1.9875
# Test Accuracy: 0.5593220591545105

# %%
def predict_and_evaluate_individual_images(model, test_images, test_labels, test_df):
    # Ensure predictions are made on properly formatted data
    predicted_classes = model.predict(test_images)
    predicted_labels = np.argmax(predicted_classes, axis=-1)

    filenames = []
    actual_labels = []

    # Iterate through each sequence in test_images
    for i, (images, label) in enumerate(zip(test_images, test_labels)):
        # Retrieve the corresponding patient data from test_df
        patient_data = test_df.iloc[i]
        sequence_filenames = patient_data['Filename'].split(',')

        # Extend the filenames list with the filenames for this patient
        filenames.extend(sequence_filenames)

        # Extend actual_labels with the actual label repeated for each image in the sequence
        actual_label = patient_data['Label']
        actual_labels.extend([actual_label] * len(sequence_filenames))

        # Check for data consistency
        if len(sequence_filenames) != images.shape[0]:
            print(f"Data mismatch for index {i}: Number of filenames does not match number of images.")
            continue

    # Ensure that the number of predicted labels matches the number of filenames
    if len(filenames) != len(predicted_labels):
        raise ValueError("Mismatch in the number of filenames and number of predicted labels.")

    # Map predicted indices back to labels if necessary
    mapped_predicted_labels = [test_df['Label'].unique()[pred] for pred in predicted_labels]

    # Create a DataFrame to compare actual vs. predicted
    results_df = pd.DataFrame({
        'Filename': filenames,
        'Actual Label': actual_labels,
        'Predicted Label': mapped_predicted_labels
    })

    return results_df

# Example usage assuming the model is already trained and available
results_df = predict_and_evaluate_individual_images(model, test_images, test_labels, test_df)
print(results_df.head())
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step
# Data mismatch for index 0: Number of filenames does not match number of images.
# Data mismatch for index 1: Number of filenames does not match number of images.
# Data mismatch for index 2: Number of filenames does not match number of images.
# Data mismatch for index 3: Number of filenames does not match number of images.
# Data mismatch for index 4: Number of filenames does not match number of images.
# Data mismatch for index 5: Number of filenames does not match number of images.
# Data mismatch for index 6: Number of filenames does not match number of images.
# Data mismatch for index 7: Number of filenames does not match number of images.
# Data mismatch for index 8: Number of filenames does not match number of images.
# Data mismatch for index 9: Number of filenames does not match number of images.
# Data mismatch for index 10: Number of filenames does not match number of images.
# Data mismatch for index 11: Number of filenames does not match number of images.
# Data mismatch for index 12: Number of filenames does not match number of images.
# Data mismatch for index 13: Number of filenames does not match number of images.
# Data mismatch for index 14: Number of filenames does not match number of images.
# Data mismatch for index 15: Number of filenames does not match number of images.
# Data mismatch for index 16: Number of filenames does not match number of images.
# Data mismatch for index 17: Number of filenames does not match number of images.
# Data mismatch for index 18: Number of filenames does not match number of images.
# Data mismatch for index 19: Number of filenames does not match number of images.
# Data mismatch for index 20: Number of filenames does not match number of images.
# Data mismatch for index 21: Number of filenames does not match number of images.
# Data mismatch for index 22: Number of filenames does not match number of images.
# Data mismatch for index 23: Number of filenames does not match number of images.
# Data mismatch for index 24: Number of filenames does not match number of images.
# Data mismatch for index 25: Number of filenames does not match number of images.
# Data mismatch for index 26: Number of filenames does not match number of images.
# Data mismatch for index 27: Number of filenames does not match number of images.
# Data mismatch for index 28: Number of filenames does not match number of images.
# Data mismatch for index 29: Number of filenames does not match number of images.
# Data mismatch for index 30: Number of filenames does not match number of images.
# Data mismatch for index 31: Number of filenames does not match number of images.
# Data mismatch for index 32: Number of filenames does not match number of images.
# Data mismatch for index 33: Number of filenames does not match number of images.
# Data mismatch for index 34: Number of filenames does not match number of images.
# Data mismatch for index 35: Number of filenames does not match number of images.
# Data mismatch for index 36: Number of filenames does not match number of images.
# Data mismatch for index 37: Number of filenames does not match number of images.
# Data mismatch for index 38: Number of filenames does not match number of images.
# Data mismatch for index 39: Number of filenames does not match number of images.
# Data mismatch for index 40: Number of filenames does not match number of images.
# Data mismatch for index 41: Number of filenames does not match number of images.
# Data mismatch for index 42: Number of filenames does not match number of images.
# Data mismatch for index 43: Number of filenames does not match number of images.
# Data mismatch for index 44: Number of filenames does not match number of images.
# Data mismatch for index 45: Number of filenames does not match number of images.
# Data mismatch for index 46: Number of filenames does not match number of images.
# Data mismatch for index 47: Number of filenames does not match number of images.
# Data mismatch for index 48: Number of filenames does not match number of images.
# Data mismatch for index 49: Number of filenames does not match number of images.
# Data mismatch for index 50: Number of filenames does not match number of images.
# Data mismatch for index 51: Number of filenames does not match number of images.
# Data mismatch for index 52: Number of filenames does not match number of images.
# Data mismatch for index 53: Number of filenames does not match number of images.
# Data mismatch for index 54: Number of filenames does not match number of images.
# Data mismatch for index 55: Number of filenames does not match number of images.
# Data mismatch for index 56: Number of filenames does not match number of images.
# Data mismatch for index 57: Number of filenames does not match number of images.
# Data mismatch for index 58: Number of filenames does not match number of images.
#           Filename  Actual Label  Predicted Label
# 0  108.1_App_M.png             0                1
# 1  108.2_App_M.png             0                0
# 2                              0                1
# 3                              0                0
# 4                              0                0

# %%
results_df
# Out:
#            Filename  Actual Label  Predicted Label
# 0   108.1_App_M.png             0                1
# 1   108.2_App_M.png             0                0
# 2                               0                1
# 3                               0                0
# 4                               0                0
# 5                               0                1
# 6                               0                1
# 7                               0                0
# 8                               0                0
# 9                               0                0
# 10                              0                1
# 11                              0                1
# 12                              0                1
# 13                              0                1
# 14                              0                1
# 15  168.1_App_M.png             0                0
# 16    168.2_App.png             0                1
# 17    168.3_App.png             0                0
# 18  168.4_App_M.png             0                0
# 19    168.5_App.png             0                1
# 20    168.6_App.png             0                1
# 21    168.7_App.png             0                1
# 22    168.8_App.png             0                1
# 23    168.9_App.png             0                1
# 24                              0                1
# 25                              0                1
# 26                              0                1
# 27                              0                1
# 28                              0                1
# 29                              0                0
# 30    177.1_RLQ.png             0                0
# 31    177.2_App.png             0                0
# 32                              0                1
# 33                              0                1
# 34                              0                1
# 35                              0                1
# 36                              0                1
# 37                              0                1
# 38                              0                1
# 39                              0                0
# 40                              0                0
# 41                              0                1
# 42                              0                1
# 43                              0                1
# 44                              0                1
# 45    186.1_App.png             0                0
# 46    186.2_App.png             0                0
# 47    186.3_App.png             0                1
# 48    186.4_App.png             0                0
# 49  186.5_App_M.png             0                1
# 50    186.6_App.png             0                1
# 51    186.7_App.png             0                0
# 52                              0                1
# 53                              0                1
# 54                              0                0
# 55                              0                0
# 56                              0                0
# 57                              0                1
# 58                              0                1

# %% [markdown]
# #### Each image on its own

# %% [markdown]
# ## Load and Preprocess the Data

# %% [markdown]
# ### Without Image Editing

# %% [markdown]
# #### Loading

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from pathlib import Path
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight

def plot_images(images, titles, num_images=5):
    """Plot a sample of images, ensuring they are correctly scaled for display."""
    fig, axes = plt.subplots(1, num_images, figsize=(15, 3))
    for i, ax in enumerate(axes):
        img = images[i]
        # Normalize float images to the range [0, 1] if needed
        if img.dtype == np.float32 or img.dtype == np.float64:
            img = (img - img.min()) / (img.max() - img.min())
        ax.imshow(img, cmap='gray')  # Use cmap='gray' if images are grayscale
        ax.set_title(titles[i])
        ax.axis('off')
    plt.show()

def load_data(image_dir, label_file, target_size=(128, 128), show_examples=False, num_images=5):
    df = pd.read_csv(label_file)
    df = df[df['filename'].str.contains('.png')]
    df['path'] = df['filename'].apply(lambda x: Path(image_dir) / x)
    df = df[df['path'].apply(Path.exists)]

    images = []
    labels = []
    file_names = []
    for _, row in df.iterrows():
        try:
            img = tf.keras.preprocessing.image.load_img(row['path'], color_mode='rgb', target_size=target_size)
            img_array = tf.keras.preprocessing.image.img_to_array(img)
            images.append(img_array)
            labels.append(row['label'])
            file_names.append(row['filename'])
        except Exception as e:
            print(f"Error loading {row['path']}: {e}")

    if not images:
        print("No valid images were loaded.")
        return None, None, None

    images = np.array(images)
    labels = pd.get_dummies(labels).values
    if show_examples:
        plot_images(images[:num_images], file_names[:num_images], num_images=min(num_images, len(images)))  # Display examples

    return images, labels, pd.DataFrame({'Filename': file_names, 'Label': labels.argmax(axis=1)})

# Example usage
train_images, train_labels, train_df = load_data(TRAIN_IMAGE_PREP_DIR, 'image_labels.csv', show_examples=True)

# %% [markdown]
# #### Architecture

# %%
# Self created 

from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

def create_advanced_cnn_model(num_classes):
    model = models.Sequential([
        layers.Input(shape=(128, 128, 1)),  # Ensure the input shape matches your data
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.5),  # Dropout to prevent overfitting
        layers.Dense(num_classes, activation='softmax')  # Softmax for multiclass classification
    ])
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Assuming 'train_labels' and 'test_labels' are already in one-hot encoded form
num_classes = train_labels.shape[1]  # Adjust based on your actual setup
model = create_advanced_cnn_model(num_classes)

# %% [markdown]
# ##### ResNet

# %%
# Resnet
from tensorflow.keras.applications import ResNet50
from tensorflow.keras import layers, models

def create_resnet_model(num_classes, input_shape=(128, 128, 1)):
    base_model = ResNet50(include_top=False, weights=None, input_shape=input_shape)

    x = base_model.output
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    predictions = layers.Dense(num_classes, activation='softmax')(x)
    
    model = models.Model(inputs=base_model.input, outputs=predictions)
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Usage
num_classes = train_labels.shape[1]  # Adjust based on your actual setup
model_resnet = create_resnet_model(num_classes)

# %% [markdown]
# ##### GooLeNet

# %%
# Googlenet

from tensorflow.keras import layers, models
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Dense, Flatten, Dropout, Input
from tensorflow.keras.models import Model

def inception_module(x, filters_1x1, filters_3x3_reduce, filters_3x3, filters_5x5_reduce, filters_5x5, filters_pool_proj):
    path1 = Conv2D(filters_1x1, (1, 1), padding='same', activation='relu')(x)

    path2 = Conv2D(filters_3x3_reduce, (1, 1), padding='same', activation='relu')(x)
    path2 = Conv2D(filters_3x3, (3, 3), padding='same', activation='relu')(path2)

    path3 = Conv2D(filters_5x5_reduce, (1, 1), padding='same', activation='relu')(x)
    path3 = Conv2D(filters_5x5, (5, 5), padding='same', activation='relu')(path3)

    path4 = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    path4 = Conv2D(filters_pool_proj, (1, 1), padding='same', activation='relu')(path4)

    return layers.concatenate([path1, path2, path3, path4], axis=-1)

def create_googlenet_model(num_classes, input_shape=(128, 128, 1)):
    input_layer = Input(shape=input_shape)
    
    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu')(input_layer)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    x = Conv2D(192, (3, 3), padding='same', activation='relu')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    x = inception_module(x, 64, 96, 128, 16, 32, 32)
    x = inception_module(x, 128, 128, 192, 32, 96, 64)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    x = inception_module(x, 192, 96, 208, 16, 48, 64)
    x = inception_module(x, 160, 112, 224, 24, 64, 64)

    x = AveragePooling2D((4, 4), strides=(1, 1))(x)  # Reduced pooling window
    x = Dropout(0.4)(x)
    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    predictions = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=input_layer, outputs=predictions)
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Usage
num_classes = train_labels.shape[1]  # Adjust based on your actual setup
model_googlenet = create_googlenet_model(num_classes)

# %% [markdown]
# #### Training Process

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

model = model # for other architecture model_googlenet or model_resnet

# Adjust the learning rate directly in the optimizer
optimizer = Adam(learning_rate=0.00001)

# Callbacks to enhance training
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Train the model
history = model.fit(
    train_images, train_labels, 
    validation_split=0.2,  # Assuming you want to use a fraction of training data for validation
    epochs=100,
    callbacks=[early_stopping],
    class_weight=class_weights  # Assuming class_weights are defined
)
# Out:
# Epoch 1/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - accuracy: 0.6118 - loss: 1.9086 - val_accuracy: 0.3974 - val_loss: 6.4194
# Epoch 2/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.6237 - loss: 2.0839 - val_accuracy: 0.4199 - val_loss: 1.4258
# Epoch 3/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 75s 2s/step - accuracy: 0.5767 - loss: 1.2179 - val_accuracy: 0.2756 - val_loss: 4.2641
# Epoch 4/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 74s 2s/step - accuracy: 0.5495 - loss: 1.4953 - val_accuracy: 0.6603 - val_loss: 4.4823
# Epoch 5/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.7049 - loss: 1.9574 - val_accuracy: 0.6699 - val_loss: 2.4846
# Epoch 6/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.6714 - loss: 2.6617 - val_accuracy: 0.2468 - val_loss: 22.1463
# Epoch 7/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.5768 - loss: 3.4083 - val_accuracy: 0.3942 - val_loss: 3.9756
# Epoch 8/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.5899 - loss: 3.2118 - val_accuracy: 0.2468 - val_loss: 35.5282
# Epoch 9/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.6399 - loss: 2.2004 - val_accuracy: 0.6795 - val_loss: 4.8537
# Epoch 10/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.6443 - loss: 2.8656 - val_accuracy: 0.7981 - val_loss: 47.9145
# Epoch 11/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.6394 - loss: 3.0355 - val_accuracy: 0.3013 - val_loss: 7.6122
# Epoch 12/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.6260 - loss: 5.8168 - val_accuracy: 0.7981 - val_loss: 200.3804
# Epoch 13/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.5179 - loss: 4.6191 - val_accuracy: 0.5865 - val_loss: 12.8851
# Epoch 14/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.6509 - loss: 4.2573 - val_accuracy: 0.5994 - val_loss: 13.8181
# Epoch 15/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.6072 - loss: 5.4156 - val_accuracy: 0.5385 - val_loss: 10.5935
# Epoch 16/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.6225 - loss: 4.8184 - val_accuracy: 0.5224 - val_loss: 5.4170
# Epoch 17/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.6149 - loss: 5.6946 - val_accuracy: 0.2564 - val_loss: 25.3900
# Epoch 18/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.6345 - loss: 4.4248 - val_accuracy: 0.3782 - val_loss: 5.4919
# Epoch 19/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.6538 - loss: 5.7471 - val_accuracy: 0.5737 - val_loss: 5.7204
# Epoch 20/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.6063 - loss: 8.2749 - val_accuracy: 0.2019 - val_loss: 274.5876
# Epoch 21/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.6791 - loss: 5.8529 - val_accuracy: 0.4391 - val_loss: 7.5494
# Epoch 22/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.6849 - loss: 3.2199 - val_accuracy: 0.7372 - val_loss: 14.9835

# %% [markdown]
# #### Evaluation

# %%
# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test Accuracy: {test_acc}")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step - accuracy: 0.7600 - loss: 0.7351
# Test Accuracy: 0.7108433842658997

# %% [markdown]
# #### Show Predicted and True Labels

# %%
# Assuming 'test_images' have been loaded and 'model' has been defined and trained
predictions = model.predict(test_images)
predicted_classes = np.argmax(predictions, axis=1)

# Assuming test_labels are one-hot encoded, we get the actual class indices
actual_classes = np.argmax(test_labels, axis=1)

# Load the label file to get filenames and corresponding labels
df_test = pd.read_csv('image_labels.csv')
df_test = df_test[df_test['filename'].apply(lambda x: Path(TEST_IMAGE_PREP_DIR) / x).apply(Path.exists)]

# Ensure the DataFrame only includes files used in the test dataset
df_test = df_test[df_test['filename'].isin([f.name for f in Path(TEST_IMAGE_PREP_DIR).glob('*.png')])]

# Assuming there's an established mapping of indices to label names
labels_mapping = pd.get_dummies(df_test['label']).columns  # This assumes the original DataFrame has correct labels

predicted_labels = [labels_mapping[pred] for pred in predicted_classes]

# Create a DataFrame to compare actual vs. predicted
results_df = pd.DataFrame({
    'Filename': df_test['filename'].tolist(),
    'Actual Label': [labels_mapping[act] for act in actual_classes],
    'Predicted Label': predicted_labels
})

# Print the DataFrame
results_df
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 319ms/step
#                                           Filename     Actual Label  \
# 0                                  108.1_App_M.png     appendicitis
# 1                                  108.2_App_M.png     appendicitis
# 2                                  168.1_App_M.png     appendicitis
# 3                                    168.2_App.png     appendicitis
# 4                                    168.3_App.png     appendicitis
# 5                                  168.4_App_M.png     appendicitis
# 6                                    168.5_App.png     appendicitis
# 7                                    168.6_App.png     appendicitis
# 8                                    168.7_App.png     appendicitis
# 9                                    168.8_App.png     appendicitis
# 10                                   168.9_App.png     appendicitis
# 11                                   177.1_RLQ.png     appendicitis
# 12                                   177.2_App.png     appendicitis
# 13                                   186.1_App.png     appendicitis
# 14                                   186.2_App.png     appendicitis
# 15                                   186.3_App.png     appendicitis
# 16                                   186.4_App.png     appendicitis
# 17                                 186.5_App_M.png     appendicitis
# 18                                   186.6_App.png     appendicitis
# 19                                   186.7_App.png     appendicitis
# 20                                   190.1_App.png     appendicitis
# 21                                 190.2_App_M.png     appendicitis
# 22                                 190.3_App_M.png     appendicitis
# 23                                 190.4_App_M.png     appendicitis
# 24                                   191.1_App.png     appendicitis
# 25                                 191.2_App_M.png     appendicitis
# 26                                 196.1_App_M.png     appendicitis
# 27                                   196.2_App.png     appendicitis
# 28                                   199.1_App.png     appendicitis
# 29                                 199.2_App_M.png     appendicitis
# 30                                 199.3_App_M.png     appendicitis
# 31                                   200.1_App.png     appendicitis
# 32                                 200.2_App_M.png     appendicitis
# 33                                 200.3_App_M.png     appendicitis
# 34                                 200.4_App_M.png     appendicitis
# 35                                 211.1_App_M.png     appendicitis
# 36                                 211.2_App_M.png     appendicitis
# 37                                   211.3_App.png     appendicitis
# 38                                   211.4_App.png     appendicitis
# 39                        226.1_perforated_app.png     appendicitis
# 40                                 226.2_App_M.png     appendicitis
# 41                               24.1_Appendix.png     appendicitis
# 42     24.2_Appendix_and_surr._tissue_reaction.png     appendicitis
# 43                               24.3_Appendix.png     appendicitis
# 44                   242.1_RLQ_app_not_visible.png  no appendicitis
# 45                                 259.1_App_M.png     appendicitis
# 46                                 259.2_App_M.png     appendicitis
# 47                                   260.1_App.png     appendicitis
# 48   29.1_Appendix_and_surrounding_free_fluids.png     appendicitis
# 49   29.2_Appendix_and_surrounding_free_fluids.png     appendicitis
# 50                        29.3_Appendix_transv.png     appendicitis
# 51                               29.4_Appendix.png     appendicitis
# 52                               29.5_Appendix.png     appendicitis
# 53                   298.1_RLQ_app_not_visible.png  no appendicitis
# 54                                 309.1_App_M.png  no appendicitis
# 55                                 309.2_App_M.png  no appendicitis
# 56                                 309.3_App_M.png  no appendicitis
# 57                                 309.4_App_M.png  no appendicitis
# 58                                 309.5_App_M.png  no appendicitis
# 59                                 309.6_App_M.png  no appendicitis
# 60                                 309.7_App_M.png  no appendicitis
# 61                                 317.1_App_M.png  no appendicitis
# 62                                 317.2_App_M.png  no appendicitis
# 63                                 317.3_App_M.png  no appendicitis
# 64                                 317.4_App_M.png  no appendicitis
# 65                   330.1_RLQ_app_not_visible.png  no appendicitis
# 66                        335.1_App_perforated.png     appendicitis
# 67                   339.1_RLQ_app_not_visible.png  no appendicitis
# 68                                    35.1_App.png     appendicitis
# 69                   370.1_RLQ_app_not_visible.png  no appendicitis
# 70                                 379.1_App_M.png  no appendicitis
# 71                   382.1_RLQ_app_not_visible.png  no appendicitis
# 72                                 412.1_App_M.png  no appendicitis
# 73                   416.1_RLQ_app_not_visible.png  no appendicitis
# 74                                 420.1_App_M.png  no appendicitis
# 75                            43.1 App L and T.png     appendicitis
# 76                                    43.2_App.png     appendicitis
# 77                                    43.3_App.png     appendicitis
# 78                                    43.4_App.png     appendicitis
# 79                                   454.1_App.png     appendicitis
# 80                                   454.2_App.png     appendicitis
# 81                                 454.3_App_M.png     appendicitis
# 82                                 454.4_App_M.png     appendicitis
# 83                                   454.6_App.png     appendicitis
# 84                                  47.1_App_T.png     appendicitis
# 85                                  47.2_App_T.png     appendicitis
# 86                                  47.3_App_L.png     appendicitis
# 87                                  47.4_App_T.png     appendicitis
# 88                   481.1_RLQ_app_not_visible.png     appendicitis
# 89                                 496.1_App_M.png     appendicitis
# 90                                 496.2_App_M.png     appendicitis
# 91                                 497.1_App_M.png     appendicitis
# 92                                 497.2_App_M.png     appendicitis
# 93                                   502.1_App.png     appendicitis
# 94                   504.1_RLQ_app_not_visible.png     appendicitis
# 95                                 507.1_App_M.png     appendicitis
# 96                                 518.1_App_M.png     appendicitis
# 97                                537.10_App_M.png     appendicitis
# 98                                537.11_App_D.png     appendicitis
# 99                                537.12_App_M.png     appendicitis
# 100                                  537.1_App.png     appendicitis
# 101                                537.2_App_M.png     appendicitis
# 102                                  537.3_App.png     appendicitis
# 103                                  537.4_App.png     appendicitis
# 104                                  537.5_App.png     appendicitis
# 105                                  537.6_App.png     appendicitis
# 106                                537.7_App_M.png     appendicitis
# 107                                537.8_App_M.png     appendicitis
# 108                                  537.9_App.png     appendicitis
# 109                                538.1_App_D.png     appendicitis
# 110                                538.2_App_M.png     appendicitis
# 111                                538.3_App_M.png     appendicitis
# 112                                  538.4_App.png     appendicitis
# 113                                538.5_App_M.png     appendicitis
# 114                                543.1_App_M.png     appendicitis
# 115                                543.2_App_M.png     appendicitis
# 116                                  551.1_App.png     appendicitis
# 117                                  551.2_App.png     appendicitis
# 118                                589.1_App_D.png  no appendicitis
# 119                                620.1_App_M.png     appendicitis
# 120                                620.2_App_M.png     appendicitis
# 121                                622.1_App_M.png     appendicitis
# 122                                622.2_App_M.png     appendicitis
# 123                                622.3_App_M.png     appendicitis
# 124                                  622.4_App.png     appendicitis
# 125                                  622.5_App.png     appendicitis
# 126                                625.1_App_M.png     appendicitis
# 127                                625.2_App_M.png     appendicitis
# 128                                625.3_App_M.png     appendicitis
# 129                                625.4_App_M.png     appendicitis
# 130                                625.5_App_M.png     appendicitis
# 131                                625.6_App_M.png     appendicitis
# 132                                625.7_App_D.png     appendicitis
# 133                                703.1_App_M.png  no appendicitis
# 134                                711.1_App_M.png  no appendicitis
# 135                                  711.2_App.png  no appendicitis
# 136                                  711.3_App.png  no appendicitis
# 137                                  711.4_App.png  no appendicitis
# 138                                711.5_App_M.png  no appendicitis
# 139                                716.1_App_M.png  no appendicitis
# 140                                  745.1_RLQ.png  no appendicitis
# 141                                  775.1_App.png     appendicitis
# 142                                775.2_App_D.png     appendicitis
# 143                                775.3_App_M.png     appendicitis
# 144                                775.4_App_M.png     appendicitis
# 145                                806.1_App_M.png     appendicitis
# 146                                806.2_App_M.png     appendicitis
# 147                                  806.3_App.png     appendicitis
# 148                                  808.1_App.png     appendicitis
# 149                                808.2_App_M.png     appendicitis
# 150                                   88.1_App.png     appendicitis
# 151                                   88.2_App.png     appendicitis
# 152                                88.3_FF_PLQ.png     appendicitis
# 153                                   88.4_App.png     appendicitis
# 154                                 93.1_App_M.png  no appendicitis
# 155                                 93.2_App_M.png  no appendicitis
# 156                                 93.4_App_M.png  no appendicitis
# 157                                 93.5_App_M.png  no appendicitis
# 158                                 93.6_App_M.png  no appendicitis
# 159                                  947.1_App.png     appendicitis
# 160                                947.2_App_M.png     appendicitis
# 161                                947.3_App_M.png     appendicitis
# 162                                947.4_App_M.png     appendicitis
# 163                                  971.1_App.png  no appendicitis
# 164                                977.1_App_M.png  no appendicitis
# 165                                977.2_App_M.png  no appendicitis
#
#      Predicted Label
# 0    no appendicitis
# 1    no appendicitis
# 2       appendicitis
# 3       appendicitis
# 4    no appendicitis
# 5       appendicitis
# 6       appendicitis
# 7       appendicitis
# 8    no appendicitis
# 9    no appendicitis
# 10   no appendicitis
# 11   no appendicitis
# 12   no appendicitis
# 13      appendicitis
# 14      appendicitis
# 15      appendicitis
# 16      appendicitis
# 17      appendicitis
# 18      appendicitis
# 19      appendicitis
# 20   no appendicitis
# 21   no appendicitis
# 22   no appendicitis
# 23   no appendicitis
# 24   no appendicitis
# 25   no appendicitis
# 26      appendicitis
# 27      appendicitis
# 28   no appendicitis
# 29   no appendicitis
# 30   no appendicitis
# 31   no appendicitis
# 32   no appendicitis
# 33      appendicitis
# 34      appendicitis
# 35   no appendicitis
# 36   no appendicitis
# 37   no appendicitis
# 38   no appendicitis
# 39   no appendicitis
# 40   no appendicitis
# 41   no appendicitis
# 42   no appendicitis
# 43      appendicitis
# 44      appendicitis
# 45      appendicitis
# 46      appendicitis
# 47   no appendicitis
# 48      appendicitis
# 49   no appendicitis
# 50   no appendicitis
# 51      appendicitis
# 52   no appendicitis
# 53   no appendicitis
# 54   no appendicitis
# 55   no appendicitis
# 56   no appendicitis
# 57   no appendicitis
# 58   no appendicitis
# 59   no appendicitis
# 60   no appendicitis
# 61   no appendicitis
# 62   no appendicitis
# 63   no appendicitis
# 64      appendicitis
# 65   no appendicitis
# 66   no appendicitis
# 67   no appendicitis
# 68   no appendicitis
# 69   no appendicitis
# 70   no appendicitis
# 71   no appendicitis
# 72   no appendicitis
# 73      appendicitis
# 74   no appendicitis
# 75   no appendicitis
# 76      appendicitis
# 77      appendicitis
# 78      appendicitis
# 79   no appendicitis
# 80   no appendicitis
# 81      appendicitis
# 82      appendicitis
# 83   no appendicitis
# 84   no appendicitis
# 85   no appendicitis
# 86      appendicitis
# 87   no appendicitis
# 88      appendicitis
# 89   no appendicitis
# 90      appendicitis
# 91      appendicitis
# 92      appendicitis
# 93   no appendicitis
# 94   no appendicitis
# 95      appendicitis
# 96   no appendicitis
# 97      appendicitis
# 98   no appendicitis
# 99      appendicitis
# 100     appendicitis
# 101     appendicitis
# 102  no appendicitis
# 103  no appendicitis
# 104  no appendicitis
# 105  no appendicitis
# 106  no appendicitis
# 107  no appendicitis
# 108  no appendicitis
# 109     appendicitis
# 110  no appendicitis
# 111  no appendicitis
# 112  no appendicitis
# 113  no appendicitis
# 114  no appendicitis
# 115  no appendicitis
# 116     appendicitis
# 117     appendicitis
# 118     appendicitis
# 119  no appendicitis
# 120     appendicitis
# 121     appendicitis
# 122  no appendicitis
# 123  no appendicitis
# 124     appendicitis
# 125  no appendicitis
# 126  no appendicitis
# 127  no appendicitis
# 128  no appendicitis
# 129  no appendicitis
# 130  no appendicitis
# 131     appendicitis
# 132  no appendicitis
# 133     appendicitis
# 134     appendicitis
# 135  no appendicitis
# 136     appendicitis
# 137     appendicitis
# 138  no appendicitis
# 139     appendicitis
# 140  no appendicitis
# 141  no appendicitis
# 142     appendicitis
# 143  no appendicitis
# 144  no appendicitis
# 145  no appendicitis
# 146     appendicitis
# 147     appendicitis
# 148  no appendicitis
# 149  no appendicitis
# 150  no appendicitis
# 151  no appendicitis
# 152  no appendicitis
# 153  no appendicitis
# 154     appendicitis
# 155  no appendicitis
# 156     appendicitis
# 157  no appendicitis
# 158  no appendicitis
# 159     appendicitis
# 160     appendicitis
# 161     appendicitis
# 162     appendicitis
# 163     appendicitis
# 164     appendicitis
# 165     appendicitis

# %% [markdown]
# ### With Image Editing

# %% [markdown]
# #### Loading and Preprocessing

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from pathlib import Path
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight
import cv2

def preprocess_image(image_array):
    try:
        # Convert to grayscale if necessary
        if image_array.ndim == 3 and image_array.shape[2] == 3:
            image_array = cv2.cvtColor(image_array, cv2.COLOR_BGR2GRAY)
        elif image_array.ndim == 3 and image_array.shape[2] == 4:
            image_array = cv2.cvtColor(image_array, cv2.COLOR_BGRA2GRAY)

        # Convert to 8-bit if necessary
        if image_array.dtype != np.uint8:
            image_array = (255 * image_array).astype(np.uint8)

        # Apply CLAHE
        clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
        image_array = clahe.apply(image_array)

        # Apply Median Filtering
        image_array = cv2.medianBlur(image_array, 5)

        # Normalize the image
        image_array = image_array.astype(np.float32) / 255.0
    except Exception as e:
        print(f"Error during preprocessing: {e}")
        return None

    return image_array

def plot_images(images, titles, num_images=5):
    """Plot a sample of preprocessed images."""
    fig, axes = plt.subplots(1, num_images, figsize=(15, 3))
    for i, ax in enumerate(axes):
        if i < len(images):
            ax.imshow(images[i].squeeze(), cmap='gray')
            ax.set_title(titles[i])
            ax.axis('off')
    plt.show()

def load_data(image_dir, label_file, target_size=(128, 128), show_examples=False,  num_images=5):
    df = pd.read_csv(label_file)
    df = df[df['filename'].str.contains('.png')]
    df['path'] = df['filename'].apply(lambda x: Path(image_dir) / x)
    df = df[df['path'].apply(Path.exists)]

    images = []
    labels = []
    file_names = []
    for _, row in df.iterrows():
        try:
            img = tf.keras.preprocessing.image.load_img(row['path'], color_mode='rgb', target_size=target_size)
            img_array = tf.keras.preprocessing.image.img_to_array(img)
            processed_image = preprocess_image(img_array)
            if processed_image is not None:
                images.append(np.expand_dims(processed_image, axis=-1))
                labels.append(row['label'])
                file_names.append(row['filename'])
        except Exception as e:
            print(f"Error loading {row['path']}: {e}")

    if not images:
        print("No valid images were loaded.")
        return None, None, None

    images = np.array(images)
    labels = pd.get_dummies(labels).values

    if show_examples:
        plot_images(images[:min(num_images, len(images))], file_names[:min(num_images, len(images))], min(num_images, len(images)))

    return images, labels, pd.DataFrame({'Filename': file_names, 'Label': labels.argmax(axis=1)})

# Example usage
train_images, train_labels, train_df = load_data(TRAIN_IMAGE_PREP_DIR, 'image_labels.csv', show_examples=True)
test_images, test_labels, test_df = load_data(TEST_IMAGE_PREP_DIR, 'image_labels.csv')

if train_images is not None and train_labels is not None:
    # Calculate class weights
    def get_class_weights(y):
        classes = np.unique(y)
        weights = compute_class_weight(class_weight='balanced', classes=classes, y=y)
        class_weights_dict = dict(zip(classes, weights))
        return class_weights_dict

    train_labels_argmax = train_df['Label'].values  # Ensure this is a 1D array of your labels
    class_weights = get_class_weights(train_labels_argmax)
    print(class_weights)
else:
    print("No valid images were loaded.")
# Out:
# {0: 0.6400986031224322, 1: 2.2844574780058653}

# %% [markdown]
# #### Architecture

# %%
from tensorflow.keras import layers, models

def create_advanced_cnn_model(num_classes):
    model = models.Sequential([
        layers.Input(shape=(128, 128, 1)),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Now use the advanced model in your training setup
model = create_advanced_cnn_model(train_labels.shape[1])

# %% [markdown]
# #### Training Process

# %%
# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)

# Train the model
history = model_resnet.fit(
    train_images, train_labels, 
    validation_data=(test_images, test_labels),
    epochs=100,
    callbacks=[early_stopping, reduce_lr],
    class_weight=class_weights
)
# Out:
# Epoch 1/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - accuracy: 0.5026 - loss: 0.6513 - val_accuracy: 0.7711 - val_loss: 0.6218 - learning_rate: 1.0000e-05
# Epoch 2/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.5451 - loss: 0.6641 - val_accuracy: 0.7711 - val_loss: 0.6119 - learning_rate: 1.0000e-05
# Epoch 3/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.5585 - loss: 0.6148 - val_accuracy: 0.7711 - val_loss: 0.6073 - learning_rate: 1.0000e-05
# Epoch 4/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.6043 - loss: 0.5823 - val_accuracy: 0.7711 - val_loss: 0.6070 - learning_rate: 1.0000e-05
# Epoch 5/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.6305 - loss: 0.5859 - val_accuracy: 0.7651 - val_loss: 0.6053 - learning_rate: 1.0000e-05
# Epoch 6/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - accuracy: 0.6979 - loss: 0.5564 - val_accuracy: 0.7410 - val_loss: 0.6120 - learning_rate: 1.0000e-05
# Epoch 7/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.7316 - loss: 0.5127 - val_accuracy: 0.6928 - val_loss: 0.6394 - learning_rate: 1.0000e-05
# Epoch 8/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.7774 - loss: 0.4693 - val_accuracy: 0.7410 - val_loss: 0.6004 - learning_rate: 1.0000e-05
# Epoch 9/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - accuracy: 0.8366 - loss: 0.4098 - val_accuracy: 0.6627 - val_loss: 0.6624 - learning_rate: 1.0000e-05
# Epoch 10/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.8708 - loss: 0.3725 - val_accuracy: 0.6687 - val_loss: 0.6909 - learning_rate: 1.0000e-05
# Epoch 11/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.9095 - loss: 0.3182 - val_accuracy: 0.7108 - val_loss: 0.6310 - learning_rate: 1.0000e-05
# Epoch 12/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.9119 - loss: 0.3308 - val_accuracy: 0.6747 - val_loss: 0.6993 - learning_rate: 1.0000e-05
# Epoch 13/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.9173 - loss: 0.2710 - val_accuracy: 0.6988 - val_loss: 0.6477 - learning_rate: 1.0000e-05
# Epoch 14/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.9187 - loss: 0.2983 - val_accuracy: 0.7229 - val_loss: 0.5975 - learning_rate: 1.0000e-05
# Epoch 15/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.9374 - loss: 0.2755 - val_accuracy: 0.6145 - val_loss: 0.8579 - learning_rate: 1.0000e-05
# Epoch 16/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.9579 - loss: 0.2184 - val_accuracy: 0.6687 - val_loss: 0.7506 - learning_rate: 1.0000e-05
# Epoch 17/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.9603 - loss: 0.2021 - val_accuracy: 0.6747 - val_loss: 0.7804 - learning_rate: 1.0000e-05
# Epoch 18/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.9454 - loss: 0.2152 - val_accuracy: 0.6867 - val_loss: 0.7746 - learning_rate: 1.0000e-05
# Epoch 19/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - accuracy: 0.9571 - loss: 0.1629 - val_accuracy: 0.6928 - val_loss: 0.7699 - learning_rate: 1.0000e-05
# Epoch 20/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - accuracy: 0.9710 - loss: 0.1873 - val_accuracy: 0.7410 - val_loss: 0.6996 - learning_rate: 1.0000e-05
# Epoch 21/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.9747 - loss: 0.1310 - val_accuracy: 0.6265 - val_loss: 1.1456 - learning_rate: 1.0000e-05
# Epoch 22/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.9782 - loss: 0.1307 - val_accuracy: 0.7108 - val_loss: 0.8019 - learning_rate: 1.0000e-05
# Epoch 23/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.9670 - loss: 0.1390 - val_accuracy: 0.7048 - val_loss: 0.8326 - learning_rate: 1.0000e-05
# Epoch 24/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.9799 - loss: 0.1073 - val_accuracy: 0.6867 - val_loss: 0.9423 - learning_rate: 1.0000e-05
# Epoch 25/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9713 - loss: 0.1307 - val_accuracy: 0.6747 - val_loss: 1.0341 - learning_rate: 1.0000e-05
# Epoch 26/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.9897 - loss: 0.0850 - val_accuracy: 0.6687 - val_loss: 1.0101 - learning_rate: 1.0000e-05
# Epoch 27/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.9712 - loss: 0.1055 - val_accuracy: 0.6928 - val_loss: 1.0404 - learning_rate: 1.0000e-05
# Epoch 28/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - accuracy: 0.9811 - loss: 0.0953 - val_accuracy: 0.6867 - val_loss: 1.0195 - learning_rate: 1.0000e-05
# Epoch 29/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9828 - loss: 0.0905 - val_accuracy: 0.6867 - val_loss: 1.0308 - learning_rate: 1.0000e-05
# Epoch 30/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - accuracy: 0.9780 - loss: 0.0981 - val_accuracy: 0.6265 - val_loss: 1.2327 - learning_rate: 1.0000e-05
# Epoch 31/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.9874 - loss: 0.0901 - val_accuracy: 0.6687 - val_loss: 1.1844 - learning_rate: 1.0000e-05
# Epoch 32/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.9887 - loss: 0.0693 - val_accuracy: 0.6386 - val_loss: 1.3487 - learning_rate: 1.0000e-05
# Epoch 33/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - accuracy: 0.9817 - loss: 0.0797 - val_accuracy: 0.6506 - val_loss: 1.2851 - learning_rate: 1.0000e-05
# Epoch 34/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.9903 - loss: 0.0641 - val_accuracy: 0.5964 - val_loss: 1.4696 - learning_rate: 1.0000e-05

# %% [markdown]
# #### Evaluation

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(test_images, test_labels)

print(f"Test Accuracy: {test_acc}")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.4827 - loss: 0.6677
# Test Accuracy: 0.5060241222381592

# %% [markdown]
# #### Show predicted and true Labels

# %%
# Assuming 'test_images' have been loaded and 'model' has been defined and trained
predictions = model.predict(test_images)
predicted_classes = np.argmax(predictions, axis=1)

# Assuming test_labels are one-hot encoded, we get the actual class indices
actual_classes = np.argmax(test_labels, axis=1)

# Load the label file to get filenames and corresponding labels
df_test = pd.read_csv('image_labels.csv')
df_test = df_test[df_test['filename'].apply(lambda x: Path(TEST_IMAGE_PREP_DIR) / x).apply(Path.exists)]

# Ensure the DataFrame only includes files used in the test dataset
df_test = df_test[df_test['filename'].isin([f.name for f in Path(TEST_IMAGE_PREP_DIR).glob('*.png')])]

# Map indices back to actual labels
# Assuming you have a label encoding mechanism or the labels are already named in 'df_test'
labels_mapping = pd.get_dummies(df_test['label']).columns  # This extracts label names from one-hot encoding

predicted_labels = [labels_mapping[pred] for pred in predicted_classes]

# Create a DataFrame to compare actual vs. predicted
results_df = pd.DataFrame({
    'Filename': df_test['filename'],
    'Actual Label': [labels_mapping[act] for act in actual_classes],
    'Predicted Label': predicted_labels
})

# Print the DataFrame
results_df
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step
#                                            Filename     Actual Label  \
# 1558                                108.1_App_M.png     appendicitis
# 1559                                108.2_App_M.png     appendicitis
# 1560                                168.1_App_M.png     appendicitis
# 1561                                  168.2_App.png     appendicitis
# 1562                                  168.3_App.png     appendicitis
# 1563                                168.4_App_M.png     appendicitis
# 1564                                  168.5_App.png     appendicitis
# 1565                                  168.6_App.png     appendicitis
# 1566                                  168.7_App.png     appendicitis
# 1567                                  168.8_App.png     appendicitis
# 1568                                  168.9_App.png     appendicitis
# 1569                                  177.1_RLQ.png     appendicitis
# 1570                                  177.2_App.png     appendicitis
# 1571                                  186.1_App.png     appendicitis
# 1572                                  186.2_App.png     appendicitis
# 1573                                  186.3_App.png     appendicitis
# 1574                                  186.4_App.png     appendicitis
# 1575                                186.5_App_M.png     appendicitis
# 1576                                  186.6_App.png     appendicitis
# 1577                                  186.7_App.png     appendicitis
# 1578                                  190.1_App.png     appendicitis
# 1579                                190.2_App_M.png     appendicitis
# 1580                                190.3_App_M.png     appendicitis
# 1581                                190.4_App_M.png     appendicitis
# 1582                                  191.1_App.png     appendicitis
# 1583                                191.2_App_M.png     appendicitis
# 1584                                196.1_App_M.png     appendicitis
# 1585                                  196.2_App.png     appendicitis
# 1586                                  199.1_App.png     appendicitis
# 1587                                199.2_App_M.png     appendicitis
# 1588                                199.3_App_M.png     appendicitis
# 1589                                  200.1_App.png     appendicitis
# 1590                                200.2_App_M.png     appendicitis
# 1591                                200.3_App_M.png     appendicitis
# 1592                                200.4_App_M.png     appendicitis
# 1593                                211.1_App_M.png     appendicitis
# 1594                                211.2_App_M.png     appendicitis
# 1595                                  211.3_App.png     appendicitis
# 1596                                  211.4_App.png     appendicitis
# 1597                       226.1_perforated_app.png     appendicitis
# 1598                                226.2_App_M.png     appendicitis
# 1599                              24.1_Appendix.png     appendicitis
# 1600    24.2_Appendix_and_surr._tissue_reaction.png     appendicitis
# 1601                              24.3_Appendix.png     appendicitis
# 1602                  242.1_RLQ_app_not_visible.png  no appendicitis
# 1603                                259.1_App_M.png     appendicitis
# 1604                                259.2_App_M.png     appendicitis
# 1605                                  260.1_App.png     appendicitis
# 1606  29.1_Appendix_and_surrounding_free_fluids.png     appendicitis
# 1607  29.2_Appendix_and_surrounding_free_fluids.png     appendicitis
# 1608                       29.3_Appendix_transv.png     appendicitis
# 1609                              29.4_Appendix.png     appendicitis
# 1610                              29.5_Appendix.png     appendicitis
# 1611                  298.1_RLQ_app_not_visible.png  no appendicitis
# 1612                                309.1_App_M.png  no appendicitis
# 1613                                309.2_App_M.png  no appendicitis
# 1614                                309.3_App_M.png  no appendicitis
# 1615                                309.4_App_M.png  no appendicitis
# 1616                                309.5_App_M.png  no appendicitis
# 1617                                309.6_App_M.png  no appendicitis
# 1618                                309.7_App_M.png  no appendicitis
# 1619                                317.1_App_M.png  no appendicitis
# 1620                                317.2_App_M.png  no appendicitis
# 1621                                317.3_App_M.png  no appendicitis
# 1622                                317.4_App_M.png  no appendicitis
# 1623                  330.1_RLQ_app_not_visible.png  no appendicitis
# 1624                       335.1_App_perforated.png     appendicitis
# 1625                  339.1_RLQ_app_not_visible.png  no appendicitis
# 1626                                   35.1_App.png     appendicitis
# 1627                  370.1_RLQ_app_not_visible.png  no appendicitis
# 1628                                379.1_App_M.png  no appendicitis
# 1629                  382.1_RLQ_app_not_visible.png  no appendicitis
# 1630                                412.1_App_M.png  no appendicitis
# 1631                  416.1_RLQ_app_not_visible.png  no appendicitis
# 1632                                420.1_App_M.png  no appendicitis
# 1633                           43.1 App L and T.png     appendicitis
# 1634                                   43.2_App.png     appendicitis
# 1635                                   43.3_App.png     appendicitis
# 1636                                   43.4_App.png     appendicitis
# 1637                                  454.1_App.png     appendicitis
# 1638                                  454.2_App.png     appendicitis
# 1639                                454.3_App_M.png     appendicitis
# 1640                                454.4_App_M.png     appendicitis
# 1641                                  454.6_App.png     appendicitis
# 1642                                 47.1_App_T.png     appendicitis
# 1643                                 47.2_App_T.png     appendicitis
# 1644                                 47.3_App_L.png     appendicitis
# 1645                                 47.4_App_T.png     appendicitis
# 1646                  481.1_RLQ_app_not_visible.png     appendicitis
# 1647                                496.1_App_M.png     appendicitis
# 1648                                496.2_App_M.png     appendicitis
# 1649                                497.1_App_M.png     appendicitis
# 1650                                497.2_App_M.png     appendicitis
# 1651                                  502.1_App.png     appendicitis
# 1652                  504.1_RLQ_app_not_visible.png     appendicitis
# 1653                                507.1_App_M.png     appendicitis
# 1654                                518.1_App_M.png     appendicitis
# 1655                               537.10_App_M.png     appendicitis
# 1656                               537.11_App_D.png     appendicitis
# 1657                               537.12_App_M.png     appendicitis
# 1658                                  537.1_App.png     appendicitis
# 1659                                537.2_App_M.png     appendicitis
# 1660                                  537.3_App.png     appendicitis
# 1661                                  537.4_App.png     appendicitis
# 1662                                  537.5_App.png     appendicitis
# 1663                                  537.6_App.png     appendicitis
# 1664                                537.7_App_M.png     appendicitis
# 1665                                537.8_App_M.png     appendicitis
# 1666                                  537.9_App.png     appendicitis
# 1667                                538.1_App_D.png     appendicitis
# 1668                                538.2_App_M.png     appendicitis
# 1669                                538.3_App_M.png     appendicitis
# 1670                                  538.4_App.png     appendicitis
# 1671                                538.5_App_M.png     appendicitis
# 1672                                543.1_App_M.png     appendicitis
# 1673                                543.2_App_M.png     appendicitis
# 1674                                  551.1_App.png     appendicitis
# 1675                                  551.2_App.png     appendicitis
# 1676                                589.1_App_D.png  no appendicitis
# 1677                                620.1_App_M.png     appendicitis
# 1678                                620.2_App_M.png     appendicitis
# 1679                                622.1_App_M.png     appendicitis
# 1680                                622.2_App_M.png     appendicitis
# 1681                                622.3_App_M.png     appendicitis
# 1682                                  622.4_App.png     appendicitis
# 1683                                  622.5_App.png     appendicitis
# 1684                                625.1_App_M.png     appendicitis
# 1685                                625.2_App_M.png     appendicitis
# 1686                                625.3_App_M.png     appendicitis
# 1687                                625.4_App_M.png     appendicitis
# 1688                                625.5_App_M.png     appendicitis
# 1689                                625.6_App_M.png     appendicitis
# 1690                                625.7_App_D.png     appendicitis
# 1691                                703.1_App_M.png  no appendicitis
# 1692                                711.1_App_M.png  no appendicitis
# 1693                                  711.2_App.png  no appendicitis
# 1694                                  711.3_App.png  no appendicitis
# 1695                                  711.4_App.png  no appendicitis
# 1696                                711.5_App_M.png  no appendicitis
# 1697                                716.1_App_M.png  no appendicitis
# 1698                                  745.1_RLQ.png  no appendicitis
# 1699                                  775.1_App.png     appendicitis
# 1700                                775.2_App_D.png     appendicitis
# 1701                                775.3_App_M.png     appendicitis
# 1702                                775.4_App_M.png     appendicitis
# 1703                                806.1_App_M.png     appendicitis
# 1704                                806.2_App_M.png     appendicitis
# 1705                                  806.3_App.png     appendicitis
# 1706                                  808.1_App.png     appendicitis
# 1707                                808.2_App_M.png     appendicitis
# 1708                                   88.1_App.png     appendicitis
# 1709                                   88.2_App.png     appendicitis
# 1710                                88.3_FF_PLQ.png     appendicitis
# 1711                                   88.4_App.png     appendicitis
# 1712                                 93.1_App_M.png  no appendicitis
# 1713                                 93.2_App_M.png  no appendicitis
# 1714                                 93.4_App_M.png  no appendicitis
# 1715                                 93.5_App_M.png  no appendicitis
# 1716                                 93.6_App_M.png  no appendicitis
# 1717                                  947.1_App.png     appendicitis
# 1718                                947.2_App_M.png     appendicitis
# 1719                                947.3_App_M.png     appendicitis
# 1720                                947.4_App_M.png     appendicitis
# 1721                                  971.1_App.png  no appendicitis
# 1722                                977.1_App_M.png  no appendicitis
# 1723                                977.2_App_M.png  no appendicitis
#
#       Predicted Label
# 1558     appendicitis
# 1559     appendicitis
# 1560     appendicitis
# 1561  no appendicitis
# 1562  no appendicitis
# 1563  no appendicitis
# 1564  no appendicitis
# 1565  no appendicitis
# 1566  no appendicitis
# 1567  no appendicitis
# 1568  no appendicitis
# 1569  no appendicitis
# 1570  no appendicitis
# 1571     appendicitis
# 1572  no appendicitis
# 1573  no appendicitis
# 1574  no appendicitis
# 1575  no appendicitis
# 1576  no appendicitis
# 1577  no appendicitis
# 1578     appendicitis
# 1579  no appendicitis
# 1580     appendicitis
# 1581     appendicitis
# 1582     appendicitis
# 1583  no appendicitis
# 1584  no appendicitis
# 1585  no appendicitis
# 1586  no appendicitis
# 1587     appendicitis
# 1588  no appendicitis
# 1589     appendicitis
# 1590     appendicitis
# 1591     appendicitis
# 1592     appendicitis
# 1593     appendicitis
# 1594     appendicitis
# 1595     appendicitis
# 1596     appendicitis
# 1597     appendicitis
# 1598     appendicitis
# 1599  no appendicitis
# 1600  no appendicitis
# 1601     appendicitis
# 1602  no appendicitis
# 1603     appendicitis
# 1604     appendicitis
# 1605  no appendicitis
# 1606  no appendicitis
# 1607  no appendicitis
# 1608     appendicitis
# 1609     appendicitis
# 1610  no appendicitis
# 1611     appendicitis
# 1612     appendicitis
# 1613     appendicitis
# 1614  no appendicitis
# 1615  no appendicitis
# 1616  no appendicitis
# 1617  no appendicitis
# 1618  no appendicitis
# 1619  no appendicitis
# 1620     appendicitis
# 1621  no appendicitis
# 1622     appendicitis
# 1623     appendicitis
# 1624  no appendicitis
# 1625  no appendicitis
# 1626     appendicitis
# 1627  no appendicitis
# 1628  no appendicitis
# 1629  no appendicitis
# 1630     appendicitis
# 1631  no appendicitis
# 1632  no appendicitis
# 1633     appendicitis
# 1634  no appendicitis
# 1635  no appendicitis
# 1636  no appendicitis
# 1637     appendicitis
# 1638     appendicitis
# 1639     appendicitis
# 1640     appendicitis
# 1641     appendicitis
# 1642     appendicitis
# 1643  no appendicitis
# 1644     appendicitis
# 1645  no appendicitis
# 1646  no appendicitis
# 1647     appendicitis
# 1648     appendicitis
# 1649     appendicitis
# 1650     appendicitis
# 1651  no appendicitis
# 1652  no appendicitis
# 1653     appendicitis
# 1654     appendicitis
# 1655     appendicitis
# 1656     appendicitis
# 1657     appendicitis
# 1658     appendicitis
# 1659     appendicitis
# 1660  no appendicitis
# 1661  no appendicitis
# 1662  no appendicitis
# 1663  no appendicitis
# 1664     appendicitis
# 1665  no appendicitis
# 1666     appendicitis
# 1667  no appendicitis
# 1668  no appendicitis
# 1669     appendicitis
# 1670     appendicitis
# 1671     appendicitis
# 1672     appendicitis
# 1673  no appendicitis
# 1674  no appendicitis
# 1675  no appendicitis
# 1676     appendicitis
# 1677  no appendicitis
# 1678  no appendicitis
# 1679  no appendicitis
# 1680  no appendicitis
# 1681  no appendicitis
# 1682  no appendicitis
# 1683  no appendicitis
# 1684  no appendicitis
# 1685  no appendicitis
# 1686  no appendicitis
# 1687  no appendicitis
# 1688  no appendicitis
# 1689     appendicitis
# 1690  no appendicitis
# 1691     appendicitis
# 1692     appendicitis
# 1693  no appendicitis
# 1694  no appendicitis
# 1695  no appendicitis
# 1696  no appendicitis
# 1697  no appendicitis
# 1698  no appendicitis
# 1699  no appendicitis
# 1700  no appendicitis
# 1701     appendicitis
# 1702     appendicitis
# 1703     appendicitis
# 1704     appendicitis
# 1705     appendicitis
# 1706     appendicitis
# 1707  no appendicitis
# 1708  no appendicitis
# 1709  no appendicitis
# 1710     appendicitis
# 1711     appendicitis
# 1712  no appendicitis
# 1713     appendicitis
# 1714     appendicitis
# 1715  no appendicitis
# 1716     appendicitis
# 1717     appendicitis
# 1718     appendicitis
# 1719     appendicitis
# 1720  no appendicitis
# 1721     appendicitis
# 1722     appendicitis
# 1723     appendicitis

# %% [markdown]
# ## Plotting Model

# %%
# Print model summary
print_model_summary(model)

# %%
# !pip install pydot

# %%
#!!!! You need to install GraohViz and set path variable for this to work: https://graphviz.org/download/
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import plot_model
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.utils import plot_model

# Assuming 'model' is already created and compiled
plot_model(model, to_file='model_architecture.png', show_shapes=True, show_layer_names=True)
